# %% [markdown]
# # Cifar10 Classification

# %% [markdown]
# Until now, we have implemented several pieces of a deep learning pipeline and even trained a two-layer neural network, but all the hyperparameters were already set to some values yielding resonable results. In real-life problems, however, much of the work in a deep learning project will be geared towards finding the best hyperparameters for a certain problem. In this notebook we will explore some good practices for network debugging and hyperparameters search, as well as extending our previously binary classification neural network to a multi-class one.
#
# Let's go!

# %%
import os
print(os.getcwd())

from google.colab import drive
drive.mount('/content/drive')
# Out:
# /content
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
os.listdir()
GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = 'HW6/6/exercise_06_cleaned' # Please change to your folder
GOOGLE_DRIVE_PATH = os.path.join('/content','drive', 'My Drive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
os.chdir(GOOGLE_DRIVE_PATH)
print(os.listdir(GOOGLE_DRIVE_PATH))
# Out:
# ['__init__.py', 'create_submission.sh', 'models', 'exercise_code', '1.cifar10_classification.ipynb']

# %%
# Some lengthy setup.
import matplotlib.pyplot as plt
import numpy as np
import os

from exercise_code.networks.layer import (
    Sigmoid, 
    Relu, 
    LeakyRelu, 
    Tanh,
)
from exercise_code.data import (
    DataLoader,
    ImageFolderDataset,
    RescaleTransform,
    NormalizeTransform,
    FlattenTransform,
    ComposeTransform,
)
from exercise_code.data.image_folder_dataset import RandomHorizontalFlip
from exercise_code.networks import (
    ClassificationNet,
    BCE,
    CrossEntropyFromLogits
)

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %% [markdown]
# # 1. Quick recap (and some new things)

# %% [markdown]
# Until now, in the previous exercises, we focused on building and understanding all the necessary modules for training a simple model. We followed the Pytorch implementations closely, as this is the framework we will use later and we want you to have a smoother transition to its APIs.
#
# In the figure below you can see the main components in Pytorch. Before starting the actual exercise, we begin with a quick recap of **our implementation** of these components.
#
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p>Everything is already implemented for this part, but we <b>strongly</b> encourage you to check out the respective source files in order to have a better understanding. </p>
# </div>

# %% [markdown]
# <img src="https://cdn-images-1.medium.com/max/800/1*uZrS4KjAuSJQIJPgOiaJUg.png" style="width: 500px;">

# %% [markdown]
# ## 1.1 Dataset and Dataloader

# %% [markdown]
# Data preparation represents an important part of deep learning projects. The data comes from different sources and in different formats and is prepared differently from application to application. One part, however, is clear: because entire datasets are usually too large for us to handle at once, we train our models on smaller batches of data.
#
# The goal of the ```Dataset``` class is to encapsulate all the 'dirty' data processing: loading and cleaning the data, storing features (or names of files where features can be found) and labels, as well as providing the means for accessing individual (transformed) items of the data using the ```__getitem__()``` function and an index. You already implemented an ```ImageFolderDataset``` (in ```exercise_code/data/image_folder_dataset.py```) class in Exercise 3. We we will reuse this class here.
#
# For processing the data, you implemented several transforms in Exercise 3 (```RescaleTransform```, ```NormalizeTransform```, ```ComposeTransform```). In this exercise we are working with images, which are multidimensional arrays, but we are using simple feedforward neural network which takes a one dimensional array as an input, so it is necessary to reshape the images before feeding them into the model.
#
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p>Please check the implementation of the reshape operation in the <code>FlattenTransform</code> class, which can be found in <code>../exercise_06/exercise_code/data/image_folder_dataset.py</code>. </p>
# </div>

# %%
os.chdir("/content")

# %%
# !unzip datasets.zip
# Out:
# 串流輸出內容已截斷至最後 5000 行。
#  extracting: datasets/cifar10/cifar10/ship/5042.png
#  extracting: datasets/cifar10/cifar10/ship/5043.png
#  extracting: datasets/cifar10/cifar10/ship/5044.png
#  extracting: datasets/cifar10/cifar10/ship/5045.png
#  extracting: datasets/cifar10/cifar10/ship/5046.png
#  extracting: datasets/cifar10/cifar10/ship/5047.png
#    creating: datasets/cifar10/cifar10/truck/
#  extracting: datasets/cifar10/cifar10/truck/0001.png
#  extracting: datasets/cifar10/cifar10/truck/0002.png
#  extracting: datasets/cifar10/cifar10/truck/0003.png
#  extracting: datasets/cifar10/cifar10/truck/0004.png
#  extracting: datasets/cifar10/cifar10/truck/0005.png
#  extracting: datasets/cifar10/cifar10/truck/0006.png
#  extracting: datasets/cifar10/cifar10/truck/0007.png
#  extracting: datasets/cifar10/cifar10/truck/0008.png
#  extracting: datasets/cifar10/cifar10/truck/0009.png
#  extracting: datasets/cifar10/cifar10/truck/0010.png
#  extracting: datasets/cifar10/cifar10/truck/0011.png
#  extracting: datasets/cifar10/cifar10/truck/0012.png
#  extracting: datasets/cifar10/cifar10/truck/0013.png
#  extracting: datasets/cifar10/cifar10/truck/0014.png
#  extracting: datasets/cifar10/cifar10/truck/0015.png
#  extracting: datasets/cifar10/cifar10/truck/0016.png
#  extracting: datasets/cifar10/cifar10/truck/0017.png
#  extracting: datasets/cifar10/cifar10/truck/0018.png
#  extracting: datasets/cifar10/cifar10/truck/0019.png
#  extracting: datasets/cifar10/cifar10/truck/0020.png
#  extracting: datasets/cifar10/cifar10/truck/0021.png
#  extracting: datasets/cifar10/cifar10/truck/0022.png
#  extracting: datasets/cifar10/cifar10/truck/0023.png
#  extracting: datasets/cifar10/cifar10/truck/0024.png
#  extracting: datasets/cifar10/cifar10/truck/0025.png
#  extracting: datasets/cifar10/cifar10/truck/0026.png
#  extracting: datasets/cifar10/cifar10/truck/0027.png
#  extracting: datasets/cifar10/cifar10/truck/0028.png
#  extracting: datasets/cifar10/cifar10/truck/0029.png
#  extracting: datasets/cifar10/cifar10/truck/0030.png
#  extracting: datasets/cifar10/cifar10/truck/0031.png
#  extracting: datasets/cifar10/cifar10/truck/0032.png
#  extracting: datasets/cifar10/cifar10/truck/0033.png
#  extracting: datasets/cifar10/cifar10/truck/0034.png
#  extracting: datasets/cifar10/cifar10/truck/0035.png
#  extracting: datasets/cifar10/cifar10/truck/0036.png
#  extracting: datasets/cifar10/cifar10/truck/0037.png
#  extracting: datasets/cifar10/cifar10/truck/0038.png
#  extracting: datasets/cifar10/cifar10/truck/0039.png
#  extracting: datasets/cifar10/cifar10/truck/0040.png
#  extracting: datasets/cifar10/cifar10/truck/0041.png
#  extracting: datasets/cifar10/cifar10/truck/0042.png
#  extracting: datasets/cifar10/cifar10/truck/0043.png
#  extracting: datasets/cifar10/cifar10/truck/0044.png
#  extracting: datasets/cifar10/cifar10/truck/0045.png
#  extracting: datasets/cifar10/cifar10/truck/0046.png
#  extracting: datasets/cifar10/cifar10/truck/0047.png
#  extracting: datasets/cifar10/cifar10/truck/0048.png
#  extracting: datasets/cifar10/cifar10/truck/0049.png
#  extracting: datasets/cifar10/cifar10/truck/0050.png
#  extracting: datasets/cifar10/cifar10/truck/0051.png
#  extracting: datasets/cifar10/cifar10/truck/0052.png
#  extracting: datasets/cifar10/cifar10/truck/0053.png
#  extracting: datasets/cifar10/cifar10/truck/0054.png
#  extracting: datasets/cifar10/cifar10/truck/0055.png
#  extracting: datasets/cifar10/cifar10/truck/0056.png
#  extracting: datasets/cifar10/cifar10/truck/0057.png
#  extracting: datasets/cifar10/cifar10/truck/0058.png
#  extracting: datasets/cifar10/cifar10/truck/0059.png
#  extracting: datasets/cifar10/cifar10/truck/0060.png
#  extracting: datasets/cifar10/cifar10/truck/0061.png
#  extracting: datasets/cifar10/cifar10/truck/0062.png
#  extracting: datasets/cifar10/cifar10/truck/0063.png
#  extracting: datasets/cifar10/cifar10/truck/0064.png
#  extracting: datasets/cifar10/cifar10/truck/0065.png
#  extracting: datasets/cifar10/cifar10/truck/0066.png
#  extracting: datasets/cifar10/cifar10/truck/0067.png
#  extracting: datasets/cifar10/cifar10/truck/0068.png
#  extracting: datasets/cifar10/cifar10/truck/0069.png
#  extracting: datasets/cifar10/cifar10/truck/0070.png
#  extracting: datasets/cifar10/cifar10/truck/0071.png
#  extracting: datasets/cifar10/cifar10/truck/0072.png
#  extracting: datasets/cifar10/cifar10/truck/0073.png
#  extracting: datasets/cifar10/cifar10/truck/0074.png
#  extracting: datasets/cifar10/cifar10/truck/0075.png
#  extracting: datasets/cifar10/cifar10/truck/0076.png
#  extracting: datasets/cifar10/cifar10/truck/0077.png
#  extracting: datasets/cifar10/cifar10/truck/0078.png
#  extracting: datasets/cifar10/cifar10/truck/0079.png
#  extracting: datasets/cifar10/cifar10/truck/0080.png
#  extracting: datasets/cifar10/cifar10/truck/0081.png
#  extracting: datasets/cifar10/cifar10/truck/0082.png
#  extracting: datasets/cifar10/cifar10/truck/0083.png
#  extracting: datasets/cifar10/cifar10/truck/0084.png
#  extracting: datasets/cifar10/cifar10/truck/0085.png
#  extracting: datasets/cifar10/cifar10/truck/0086.png
#  extracting: datasets/cifar10/cifar10/truck/0087.png
#  extracting: datasets/cifar10/cifar10/truck/0088.png
#  extracting: datasets/cifar10/cifar10/truck/0089.png
#  extracting: datasets/cifar10/cifar10/truck/0090.png
#  extracting: datasets/cifar10/cifar10/truck/0091.png
#  extracting: datasets/cifar10/cifar10/truck/0092.png
#  extracting: datasets/cifar10/cifar10/truck/0093.png
#  extracting: datasets/cifar10/cifar10/truck/0094.png
#  extracting: datasets/cifar10/cifar10/truck/0095.png
#  extracting: datasets/cifar10/cifar10/truck/0096.png
#  extracting: datasets/cifar10/cifar10/truck/0097.png
#  extracting: datasets/cifar10/cifar10/truck/0098.png
#  extracting: datasets/cifar10/cifar10/truck/0099.png
#  extracting: datasets/cifar10/cifar10/truck/0100.png
#  extracting: datasets/cifar10/cifar10/truck/0101.png
#  extracting: datasets/cifar10/cifar10/truck/0102.png
#  extracting: datasets/cifar10/cifar10/truck/0103.png
#  extracting: datasets/cifar10/cifar10/truck/0104.png
#  extracting: datasets/cifar10/cifar10/truck/0105.png
#  extracting: datasets/cifar10/cifar10/truck/0106.png
#  extracting: datasets/cifar10/cifar10/truck/0107.png
#  extracting: datasets/cifar10/cifar10/truck/0108.png
#  extracting: datasets/cifar10/cifar10/truck/0109.png
#  extracting: datasets/cifar10/cifar10/truck/0110.png
#  extracting: datasets/cifar10/cifar10/truck/0111.png
#  extracting: datasets/cifar10/cifar10/truck/0112.png
#  extracting: datasets/cifar10/cifar10/truck/0113.png
#  extracting: datasets/cifar10/cifar10/truck/0114.png
#  extracting: datasets/cifar10/cifar10/truck/0115.png
#  extracting: datasets/cifar10/cifar10/truck/0116.png
#  extracting: datasets/cifar10/cifar10/truck/0117.png
#  extracting: datasets/cifar10/cifar10/truck/0118.png
#  extracting: datasets/cifar10/cifar10/truck/0119.png
#  extracting: datasets/cifar10/cifar10/truck/0120.png
#  extracting: datasets/cifar10/cifar10/truck/0121.png
#  extracting: datasets/cifar10/cifar10/truck/0122.png
#  extracting: datasets/cifar10/cifar10/truck/0123.png
#  extracting: datasets/cifar10/cifar10/truck/0124.png
#  extracting: datasets/cifar10/cifar10/truck/0125.png
#  extracting: datasets/cifar10/cifar10/truck/0126.png
#  extracting: datasets/cifar10/cifar10/truck/0127.png
#  extracting: datasets/cifar10/cifar10/truck/0128.png
#  extracting: datasets/cifar10/cifar10/truck/0129.png
#  extracting: datasets/cifar10/cifar10/truck/0130.png
#  extracting: datasets/cifar10/cifar10/truck/0131.png
#  extracting: datasets/cifar10/cifar10/truck/0132.png
#  extracting: datasets/cifar10/cifar10/truck/0133.png
#  extracting: datasets/cifar10/cifar10/truck/0134.png
#  extracting: datasets/cifar10/cifar10/truck/0135.png
#  extracting: datasets/cifar10/cifar10/truck/0136.png
#  extracting: datasets/cifar10/cifar10/truck/0137.png
#  extracting: datasets/cifar10/cifar10/truck/0138.png
#  extracting: datasets/cifar10/cifar10/truck/0139.png
#  extracting: datasets/cifar10/cifar10/truck/0140.png
#  extracting: datasets/cifar10/cifar10/truck/0141.png
#  extracting: datasets/cifar10/cifar10/truck/0142.png
#  extracting: datasets/cifar10/cifar10/truck/0143.png
#  extracting: datasets/cifar10/cifar10/truck/0144.png
#  extracting: datasets/cifar10/cifar10/truck/0145.png
#  extracting: datasets/cifar10/cifar10/truck/0146.png
#  extracting: datasets/cifar10/cifar10/truck/0147.png
#  extracting: datasets/cifar10/cifar10/truck/0148.png
#  extracting: datasets/cifar10/cifar10/truck/0149.png
#  extracting: datasets/cifar10/cifar10/truck/0150.png
#  extracting: datasets/cifar10/cifar10/truck/0151.png
#  extracting: datasets/cifar10/cifar10/truck/0152.png
#  extracting: datasets/cifar10/cifar10/truck/0153.png
#  extracting: datasets/cifar10/cifar10/truck/0154.png
#  extracting: datasets/cifar10/cifar10/truck/0155.png
#  extracting: datasets/cifar10/cifar10/truck/0156.png
#  extracting: datasets/cifar10/cifar10/truck/0157.png
#  extracting: datasets/cifar10/cifar10/truck/0158.png
#  extracting: datasets/cifar10/cifar10/truck/0159.png
#  extracting: datasets/cifar10/cifar10/truck/0160.png
#  extracting: datasets/cifar10/cifar10/truck/0161.png
#  extracting: datasets/cifar10/cifar10/truck/0162.png
#  extracting: datasets/cifar10/cifar10/truck/0163.png
#  extracting: datasets/cifar10/cifar10/truck/0164.png
#  extracting: datasets/cifar10/cifar10/truck/0165.png
#  extracting: datasets/cifar10/cifar10/truck/0166.png
#  extracting: datasets/cifar10/cifar10/truck/0167.png
#  extracting: datasets/cifar10/cifar10/truck/0168.png
#  extracting: datasets/cifar10/cifar10/truck/0169.png
#  extracting: datasets/cifar10/cifar10/truck/0170.png
#  extracting: datasets/cifar10/cifar10/truck/0171.png
#  extracting: datasets/cifar10/cifar10/truck/0172.png
#  extracting: datasets/cifar10/cifar10/truck/0173.png
#  extracting: datasets/cifar10/cifar10/truck/0174.png
#  extracting: datasets/cifar10/cifar10/truck/0175.png
#  extracting: datasets/cifar10/cifar10/truck/0176.png
#  extracting: datasets/cifar10/cifar10/truck/0177.png
#  extracting: datasets/cifar10/cifar10/truck/0178.png
#  extracting: datasets/cifar10/cifar10/truck/0179.png
#  extracting: datasets/cifar10/cifar10/truck/0180.png
#  extracting: datasets/cifar10/cifar10/truck/0181.png
#  extracting: datasets/cifar10/cifar10/truck/0182.png
#  extracting: datasets/cifar10/cifar10/truck/0183.png
#  extracting: datasets/cifar10/cifar10/truck/0184.png
#  extracting: datasets/cifar10/cifar10/truck/0185.png
#  extracting: datasets/cifar10/cifar10/truck/0186.png
#  extracting: datasets/cifar10/cifar10/truck/0187.png
#  extracting: datasets/cifar10/cifar10/truck/0188.png
#  extracting: datasets/cifar10/cifar10/truck/0189.png
#  extracting: datasets/cifar10/cifar10/truck/0190.png
#  extracting: datasets/cifar10/cifar10/truck/0191.png
#   inflating: datasets/cifar10/cifar10/truck/0192.png
#  extracting: datasets/cifar10/cifar10/truck/0193.png
#  extracting: datasets/cifar10/cifar10/truck/0194.png
#  extracting: datasets/cifar10/cifar10/truck/0195.png
#  extracting: datasets/cifar10/cifar10/truck/0196.png
#  extracting: datasets/cifar10/cifar10/truck/0197.png
#  extracting: datasets/cifar10/cifar10/truck/0198.png
#  extracting: datasets/cifar10/cifar10/truck/0199.png
#  extracting: datasets/cifar10/cifar10/truck/0200.png
#  extracting: datasets/cifar10/cifar10/truck/0201.png
#  extracting: datasets/cifar10/cifar10/truck/0202.png
#  extracting: datasets/cifar10/cifar10/truck/0203.png
#  extracting: datasets/cifar10/cifar10/truck/0204.png
#  extracting: datasets/cifar10/cifar10/truck/0205.png
#  extracting: datasets/cifar10/cifar10/truck/0206.png
#  extracting: datasets/cifar10/cifar10/truck/0207.png
#  extracting: datasets/cifar10/cifar10/truck/0208.png
#  extracting: datasets/cifar10/cifar10/truck/0209.png
#  extracting: datasets/cifar10/cifar10/truck/0210.png
#  extracting: datasets/cifar10/cifar10/truck/0211.png
#  extracting: datasets/cifar10/cifar10/truck/0212.png
#  extracting: datasets/cifar10/cifar10/truck/0213.png
#  extracting: datasets/cifar10/cifar10/truck/0214.png
#  extracting: datasets/cifar10/cifar10/truck/0215.png
#  extracting: datasets/cifar10/cifar10/truck/0216.png
#  extracting: datasets/cifar10/cifar10/truck/0217.png
#  extracting: datasets/cifar10/cifar10/truck/0218.png
#  extracting: datasets/cifar10/cifar10/truck/0219.png
#  extracting: datasets/cifar10/cifar10/truck/0220.png
#  extracting: datasets/cifar10/cifar10/truck/0221.png
#  extracting: datasets/cifar10/cifar10/truck/0222.png
#  extracting: datasets/cifar10/cifar10/truck/0223.png
#  extracting: datasets/cifar10/cifar10/truck/0224.png
#  extracting: datasets/cifar10/cifar10/truck/0225.png
#  extracting: datasets/cifar10/cifar10/truck/0226.png
#  extracting: datasets/cifar10/cifar10/truck/0227.png
#  extracting: datasets/cifar10/cifar10/truck/0228.png
#  extracting: datasets/cifar10/cifar10/truck/0229.png
#  extracting: datasets/cifar10/cifar10/truck/0230.png
#  extracting: datasets/cifar10/cifar10/truck/0231.png
#  extracting: datasets/cifar10/cifar10/truck/0232.png
#  extracting: datasets/cifar10/cifar10/truck/0233.png
#  extracting: datasets/cifar10/cifar10/truck/0234.png
#  extracting: datasets/cifar10/cifar10/truck/0235.png
#  extracting: datasets/cifar10/cifar10/truck/0236.png
#  extracting: datasets/cifar10/cifar10/truck/0237.png
#  extracting: datasets/cifar10/cifar10/truck/0238.png
#  extracting: datasets/cifar10/cifar10/truck/0239.png
#  extracting: datasets/cifar10/cifar10/truck/0240.png
#  extracting: datasets/cifar10/cifar10/truck/0241.png
#  extracting: datasets/cifar10/cifar10/truck/0242.png
#  extracting: datasets/cifar10/cifar10/truck/0243.png
#  extracting: datasets/cifar10/cifar10/truck/0244.png
#  extracting: datasets/cifar10/cifar10/truck/0245.png
#  extracting: datasets/cifar10/cifar10/truck/0246.png
#  extracting: datasets/cifar10/cifar10/truck/0247.png
#  extracting: datasets/cifar10/cifar10/truck/0248.png
#  extracting: datasets/cifar10/cifar10/truck/0249.png
#  extracting: datasets/cifar10/cifar10/truck/0250.png
#  extracting: datasets/cifar10/cifar10/truck/0251.png
#  extracting: datasets/cifar10/cifar10/truck/0252.png
#  extracting: datasets/cifar10/cifar10/truck/0253.png
#  extracting: datasets/cifar10/cifar10/truck/0254.png
#  extracting: datasets/cifar10/cifar10/truck/0255.png
#  extracting: datasets/cifar10/cifar10/truck/0256.png
#  extracting: datasets/cifar10/cifar10/truck/0257.png
#  extracting: datasets/cifar10/cifar10/truck/0258.png
#  extracting: datasets/cifar10/cifar10/truck/0259.png
#  extracting: datasets/cifar10/cifar10/truck/0260.png
#  extracting: datasets/cifar10/cifar10/truck/0261.png
#  extracting: datasets/cifar10/cifar10/truck/0262.png
#  extracting: datasets/cifar10/cifar10/truck/0263.png
#  extracting: datasets/cifar10/cifar10/truck/0264.png
#  extracting: datasets/cifar10/cifar10/truck/0265.png
#  extracting: datasets/cifar10/cifar10/truck/0266.png
#  extracting: datasets/cifar10/cifar10/truck/0267.png
#  extracting: datasets/cifar10/cifar10/truck/0268.png
#  extracting: datasets/cifar10/cifar10/truck/0269.png
#  extracting: datasets/cifar10/cifar10/truck/0270.png
#  extracting: datasets/cifar10/cifar10/truck/0271.png
#  extracting: datasets/cifar10/cifar10/truck/0272.png
#  extracting: datasets/cifar10/cifar10/truck/0273.png
#  extracting: datasets/cifar10/cifar10/truck/0274.png
#  extracting: datasets/cifar10/cifar10/truck/0275.png
#  extracting: datasets/cifar10/cifar10/truck/0276.png
#  extracting: datasets/cifar10/cifar10/truck/0277.png
#  extracting: datasets/cifar10/cifar10/truck/0278.png
#  extracting: datasets/cifar10/cifar10/truck/0279.png
#  extracting: datasets/cifar10/cifar10/truck/0280.png
#  extracting: datasets/cifar10/cifar10/truck/0281.png
#  extracting: datasets/cifar10/cifar10/truck/0282.png
#  extracting: datasets/cifar10/cifar10/truck/0283.png
#  extracting: datasets/cifar10/cifar10/truck/0284.png
#  extracting: datasets/cifar10/cifar10/truck/0285.png
#  extracting: datasets/cifar10/cifar10/truck/0286.png
#  extracting: datasets/cifar10/cifar10/truck/0287.png
#  extracting: datasets/cifar10/cifar10/truck/0288.png
#  extracting: datasets/cifar10/cifar10/truck/0289.png
#  extracting: datasets/cifar10/cifar10/truck/0290.png
#  extracting: datasets/cifar10/cifar10/truck/0291.png
#  extracting: datasets/cifar10/cifar10/truck/0292.png
#  extracting: datasets/cifar10/cifar10/truck/0293.png
#  extracting: datasets/cifar10/cifar10/truck/0294.png
#  extracting: datasets/cifar10/cifar10/truck/0295.png
#  extracting: datasets/cifar10/cifar10/truck/0296.png
#  extracting: datasets/cifar10/cifar10/truck/0297.png
#  extracting: datasets/cifar10/cifar10/truck/0298.png
#  extracting: datasets/cifar10/cifar10/truck/0299.png
#  extracting: datasets/cifar10/cifar10/truck/0300.png
#  extracting: datasets/cifar10/cifar10/truck/0301.png
#  extracting: datasets/cifar10/cifar10/truck/0302.png
#  extracting: datasets/cifar10/cifar10/truck/0303.png
#  extracting: datasets/cifar10/cifar10/truck/0304.png
#  extracting: datasets/cifar10/cifar10/truck/0305.png
#  extracting: datasets/cifar10/cifar10/truck/0306.png
#  extracting: datasets/cifar10/cifar10/truck/0307.png
#  extracting: datasets/cifar10/cifar10/truck/0308.png
#  extracting: datasets/cifar10/cifar10/truck/0309.png
#  extracting: datasets/cifar10/cifar10/truck/0310.png
#  extracting: datasets/cifar10/cifar10/truck/0311.png
#  extracting: datasets/cifar10/cifar10/truck/0312.png
#  extracting: datasets/cifar10/cifar10/truck/0313.png
#  extracting: datasets/cifar10/cifar10/truck/0314.png
#  extracting: datasets/cifar10/cifar10/truck/0315.png
#  extracting: datasets/cifar10/cifar10/truck/0316.png
#  extracting: datasets/cifar10/cifar10/truck/0317.png
#  extracting: datasets/cifar10/cifar10/truck/0318.png
#  extracting: datasets/cifar10/cifar10/truck/0319.png
#  extracting: datasets/cifar10/cifar10/truck/0320.png
#  extracting: datasets/cifar10/cifar10/truck/0321.png
#  extracting: datasets/cifar10/cifar10/truck/0322.png
#  extracting: datasets/cifar10/cifar10/truck/0323.png
#  extracting: datasets/cifar10/cifar10/truck/0324.png
#  extracting: datasets/cifar10/cifar10/truck/0325.png
#  extracting: datasets/cifar10/cifar10/truck/0326.png
#  extracting: datasets/cifar10/cifar10/truck/0327.png
#  extracting: datasets/cifar10/cifar10/truck/0328.png
#  extracting: datasets/cifar10/cifar10/truck/0329.png
#  extracting: datasets/cifar10/cifar10/truck/0330.png
#  extracting: datasets/cifar10/cifar10/truck/0331.png
#  extracting: datasets/cifar10/cifar10/truck/0332.png
#  extracting: datasets/cifar10/cifar10/truck/0333.png
#  extracting: datasets/cifar10/cifar10/truck/0334.png
#  extracting: datasets/cifar10/cifar10/truck/0335.png
#  extracting: datasets/cifar10/cifar10/truck/0336.png
#  extracting: datasets/cifar10/cifar10/truck/0337.png
#  extracting: datasets/cifar10/cifar10/truck/0338.png
#  extracting: datasets/cifar10/cifar10/truck/0339.png
#  extracting: datasets/cifar10/cifar10/truck/0340.png
#  extracting: datasets/cifar10/cifar10/truck/0341.png
#  extracting: datasets/cifar10/cifar10/truck/0342.png
#  extracting: datasets/cifar10/cifar10/truck/0343.png
#  extracting: datasets/cifar10/cifar10/truck/0344.png
#  extracting: datasets/cifar10/cifar10/truck/0345.png
#  extracting: datasets/cifar10/cifar10/truck/0346.png
#  extracting: datasets/cifar10/cifar10/truck/0347.png
#  extracting: datasets/cifar10/cifar10/truck/0348.png
#  extracting: datasets/cifar10/cifar10/truck/0349.png
#  extracting: datasets/cifar10/cifar10/truck/0350.png
#  extracting: datasets/cifar10/cifar10/truck/0351.png
#  extracting: datasets/cifar10/cifar10/truck/0352.png
#  extracting: datasets/cifar10/cifar10/truck/0353.png
#  extracting: datasets/cifar10/cifar10/truck/0354.png
#  extracting: datasets/cifar10/cifar10/truck/0355.png
#  extracting: datasets/cifar10/cifar10/truck/0356.png
#  extracting: datasets/cifar10/cifar10/truck/0357.png
#  extracting: datasets/cifar10/cifar10/truck/0358.png
#  extracting: datasets/cifar10/cifar10/truck/0359.png
#  extracting: datasets/cifar10/cifar10/truck/0360.png
#  extracting: datasets/cifar10/cifar10/truck/0361.png
#  extracting: datasets/cifar10/cifar10/truck/0362.png
#  extracting: datasets/cifar10/cifar10/truck/0363.png
#  extracting: datasets/cifar10/cifar10/truck/0364.png
#  extracting: datasets/cifar10/cifar10/truck/0365.png
#  extracting: datasets/cifar10/cifar10/truck/0366.png
#  extracting: datasets/cifar10/cifar10/truck/0367.png
#  extracting: datasets/cifar10/cifar10/truck/0368.png
#  extracting: datasets/cifar10/cifar10/truck/0369.png
#  extracting: datasets/cifar10/cifar10/truck/0370.png
#  extracting: datasets/cifar10/cifar10/truck/0371.png
#  extracting: datasets/cifar10/cifar10/truck/0372.png
#  extracting: datasets/cifar10/cifar10/truck/0373.png
#  extracting: datasets/cifar10/cifar10/truck/0374.png
#  extracting: datasets/cifar10/cifar10/truck/0375.png
#  extracting: datasets/cifar10/cifar10/truck/0376.png
#  extracting: datasets/cifar10/cifar10/truck/0377.png
#  extracting: datasets/cifar10/cifar10/truck/0378.png
#  extracting: datasets/cifar10/cifar10/truck/0379.png
#  extracting: datasets/cifar10/cifar10/truck/0380.png
#  extracting: datasets/cifar10/cifar10/truck/0381.png
#  extracting: datasets/cifar10/cifar10/truck/0382.png
#  extracting: datasets/cifar10/cifar10/truck/0383.png
#  extracting: datasets/cifar10/cifar10/truck/0384.png
#  extracting: datasets/cifar10/cifar10/truck/0385.png
#  extracting: datasets/cifar10/cifar10/truck/0386.png
#  extracting: datasets/cifar10/cifar10/truck/0387.png
#  extracting: datasets/cifar10/cifar10/truck/0388.png
#  extracting: datasets/cifar10/cifar10/truck/0389.png
#  extracting: datasets/cifar10/cifar10/truck/0390.png
#  extracting: datasets/cifar10/cifar10/truck/0391.png
#  extracting: datasets/cifar10/cifar10/truck/0392.png
#  extracting: datasets/cifar10/cifar10/truck/0393.png
#  extracting: datasets/cifar10/cifar10/truck/0394.png
#  extracting: datasets/cifar10/cifar10/truck/0395.png
#  extracting: datasets/cifar10/cifar10/truck/0396.png
#  extracting: datasets/cifar10/cifar10/truck/0397.png
#  extracting: datasets/cifar10/cifar10/truck/0398.png
#  extracting: datasets/cifar10/cifar10/truck/0399.png
#  extracting: datasets/cifar10/cifar10/truck/0400.png
#  extracting: datasets/cifar10/cifar10/truck/0401.png
#  extracting: datasets/cifar10/cifar10/truck/0402.png
#  extracting: datasets/cifar10/cifar10/truck/0403.png
#  extracting: datasets/cifar10/cifar10/truck/0404.png
#  extracting: datasets/cifar10/cifar10/truck/0405.png
#  extracting: datasets/cifar10/cifar10/truck/0406.png
#  extracting: datasets/cifar10/cifar10/truck/0407.png
#  extracting: datasets/cifar10/cifar10/truck/0408.png
#  extracting: datasets/cifar10/cifar10/truck/0409.png
#  extracting: datasets/cifar10/cifar10/truck/0410.png
#  extracting: datasets/cifar10/cifar10/truck/0411.png
#  extracting: datasets/cifar10/cifar10/truck/0412.png
#  extracting: datasets/cifar10/cifar10/truck/0413.png
#  extracting: datasets/cifar10/cifar10/truck/0414.png
#  extracting: datasets/cifar10/cifar10/truck/0415.png
#  extracting: datasets/cifar10/cifar10/truck/0416.png
#  extracting: datasets/cifar10/cifar10/truck/0417.png
#  extracting: datasets/cifar10/cifar10/truck/0418.png
#  extracting: datasets/cifar10/cifar10/truck/0419.png
#  extracting: datasets/cifar10/cifar10/truck/0420.png
#  extracting: datasets/cifar10/cifar10/truck/0421.png
#  extracting: datasets/cifar10/cifar10/truck/0422.png
#  extracting: datasets/cifar10/cifar10/truck/0423.png
#  extracting: datasets/cifar10/cifar10/truck/0424.png
#  extracting: datasets/cifar10/cifar10/truck/0425.png
#  extracting: datasets/cifar10/cifar10/truck/0426.png
#  extracting: datasets/cifar10/cifar10/truck/0427.png
#  extracting: datasets/cifar10/cifar10/truck/0428.png
#  extracting: datasets/cifar10/cifar10/truck/0429.png
#  extracting: datasets/cifar10/cifar10/truck/0430.png
#  extracting: datasets/cifar10/cifar10/truck/0431.png
#  extracting: datasets/cifar10/cifar10/truck/0432.png
#  extracting: datasets/cifar10/cifar10/truck/0433.png
#  extracting: datasets/cifar10/cifar10/truck/0434.png
#  extracting: datasets/cifar10/cifar10/truck/0435.png
#  extracting: datasets/cifar10/cifar10/truck/0436.png
#  extracting: datasets/cifar10/cifar10/truck/0437.png
#  extracting: datasets/cifar10/cifar10/truck/0438.png
#  extracting: datasets/cifar10/cifar10/truck/0439.png
#  extracting: datasets/cifar10/cifar10/truck/0440.png
#  extracting: datasets/cifar10/cifar10/truck/0441.png
#  extracting: datasets/cifar10/cifar10/truck/0442.png
#  extracting: datasets/cifar10/cifar10/truck/0443.png
#  extracting: datasets/cifar10/cifar10/truck/0444.png
#  extracting: datasets/cifar10/cifar10/truck/0445.png
#  extracting: datasets/cifar10/cifar10/truck/0446.png
#  extracting: datasets/cifar10/cifar10/truck/0447.png
#  extracting: datasets/cifar10/cifar10/truck/0448.png
#  extracting: datasets/cifar10/cifar10/truck/0449.png
#  extracting: datasets/cifar10/cifar10/truck/0450.png
#  extracting: datasets/cifar10/cifar10/truck/0451.png
#  extracting: datasets/cifar10/cifar10/truck/0452.png
#  extracting: datasets/cifar10/cifar10/truck/0453.png
#  extracting: datasets/cifar10/cifar10/truck/0454.png
#  extracting: datasets/cifar10/cifar10/truck/0455.png
#  extracting: datasets/cifar10/cifar10/truck/0456.png
#  extracting: datasets/cifar10/cifar10/truck/0457.png
#  extracting: datasets/cifar10/cifar10/truck/0458.png
#  extracting: datasets/cifar10/cifar10/truck/0459.png
#  extracting: datasets/cifar10/cifar10/truck/0460.png
#  extracting: datasets/cifar10/cifar10/truck/0461.png
#  extracting: datasets/cifar10/cifar10/truck/0462.png
#  extracting: datasets/cifar10/cifar10/truck/0463.png
#  extracting: datasets/cifar10/cifar10/truck/0464.png
#  extracting: datasets/cifar10/cifar10/truck/0465.png
#  extracting: datasets/cifar10/cifar10/truck/0466.png
#  extracting: datasets/cifar10/cifar10/truck/0467.png
#  extracting: datasets/cifar10/cifar10/truck/0468.png
#  extracting: datasets/cifar10/cifar10/truck/0469.png
#  extracting: datasets/cifar10/cifar10/truck/0470.png
#  extracting: datasets/cifar10/cifar10/truck/0471.png
#  extracting: datasets/cifar10/cifar10/truck/0472.png
#  extracting: datasets/cifar10/cifar10/truck/0473.png
#  extracting: datasets/cifar10/cifar10/truck/0474.png
#  extracting: datasets/cifar10/cifar10/truck/0475.png
#  extracting: datasets/cifar10/cifar10/truck/0476.png
#  extracting: datasets/cifar10/cifar10/truck/0477.png
#  extracting: datasets/cifar10/cifar10/truck/0478.png
#  extracting: datasets/cifar10/cifar10/truck/0479.png
#  extracting: datasets/cifar10/cifar10/truck/0480.png
#  extracting: datasets/cifar10/cifar10/truck/0481.png
#  extracting: datasets/cifar10/cifar10/truck/0482.png
#  extracting: datasets/cifar10/cifar10/truck/0483.png
#  extracting: datasets/cifar10/cifar10/truck/0484.png
#  extracting: datasets/cifar10/cifar10/truck/0485.png
#  extracting: datasets/cifar10/cifar10/truck/0486.png
#  extracting: datasets/cifar10/cifar10/truck/0487.png
#  extracting: datasets/cifar10/cifar10/truck/0488.png
#  extracting: datasets/cifar10/cifar10/truck/0489.png
#  extracting: datasets/cifar10/cifar10/truck/0490.png
#  extracting: datasets/cifar10/cifar10/truck/0491.png
#  extracting: datasets/cifar10/cifar10/truck/0492.png
#  extracting: datasets/cifar10/cifar10/truck/0493.png
#  extracting: datasets/cifar10/cifar10/truck/0494.png
#  extracting: datasets/cifar10/cifar10/truck/0495.png
#  extracting: datasets/cifar10/cifar10/truck/0496.png
#  extracting: datasets/cifar10/cifar10/truck/0497.png
#  extracting: datasets/cifar10/cifar10/truck/0498.png
#  extracting: datasets/cifar10/cifar10/truck/0499.png
#  extracting: datasets/cifar10/cifar10/truck/0500.png
#  extracting: datasets/cifar10/cifar10/truck/0501.png
#  extracting: datasets/cifar10/cifar10/truck/0502.png
#  extracting: datasets/cifar10/cifar10/truck/0503.png
#  extracting: datasets/cifar10/cifar10/truck/0504.png
#  extracting: datasets/cifar10/cifar10/truck/0505.png
#  extracting: datasets/cifar10/cifar10/truck/0506.png
#  extracting: datasets/cifar10/cifar10/truck/0507.png
#  extracting: datasets/cifar10/cifar10/truck/0508.png
#  extracting: datasets/cifar10/cifar10/truck/0509.png
#  extracting: datasets/cifar10/cifar10/truck/0510.png
#  extracting: datasets/cifar10/cifar10/truck/0511.png
#  extracting: datasets/cifar10/cifar10/truck/0512.png
#  extracting: datasets/cifar10/cifar10/truck/0513.png
#  extracting: datasets/cifar10/cifar10/truck/0514.png
#  extracting: datasets/cifar10/cifar10/truck/0515.png
#  extracting: datasets/cifar10/cifar10/truck/0516.png
#  extracting: datasets/cifar10/cifar10/truck/0517.png
#  extracting: datasets/cifar10/cifar10/truck/0518.png
#  extracting: datasets/cifar10/cifar10/truck/0519.png
#  extracting: datasets/cifar10/cifar10/truck/0520.png
#  extracting: datasets/cifar10/cifar10/truck/0521.png
#  extracting: datasets/cifar10/cifar10/truck/0522.png
#  extracting: datasets/cifar10/cifar10/truck/0523.png
#  extracting: datasets/cifar10/cifar10/truck/0524.png
#  extracting: datasets/cifar10/cifar10/truck/0525.png
#  extracting: datasets/cifar10/cifar10/truck/0526.png
#  extracting: datasets/cifar10/cifar10/truck/0527.png
#  extracting: datasets/cifar10/cifar10/truck/0528.png
#  extracting: datasets/cifar10/cifar10/truck/0529.png
#  extracting: datasets/cifar10/cifar10/truck/0530.png
#  extracting: datasets/cifar10/cifar10/truck/0531.png
#  extracting: datasets/cifar10/cifar10/truck/0532.png
#  extracting: datasets/cifar10/cifar10/truck/0533.png
#  extracting: datasets/cifar10/cifar10/truck/0534.png
#  extracting: datasets/cifar10/cifar10/truck/0535.png
#  extracting: datasets/cifar10/cifar10/truck/0536.png
#  extracting: datasets/cifar10/cifar10/truck/0537.png
#  extracting: datasets/cifar10/cifar10/truck/0538.png
#  extracting: datasets/cifar10/cifar10/truck/0539.png
#  extracting: datasets/cifar10/cifar10/truck/0540.png
#  extracting: datasets/cifar10/cifar10/truck/0541.png
#  extracting: datasets/cifar10/cifar10/truck/0542.png
#  extracting: datasets/cifar10/cifar10/truck/0543.png
#  extracting: datasets/cifar10/cifar10/truck/0544.png
#  extracting: datasets/cifar10/cifar10/truck/0545.png
#  extracting: datasets/cifar10/cifar10/truck/0546.png
#  extracting: datasets/cifar10/cifar10/truck/0547.png
#  extracting: datasets/cifar10/cifar10/truck/0548.png
#  extracting: datasets/cifar10/cifar10/truck/0549.png
#  extracting: datasets/cifar10/cifar10/truck/0550.png
#  extracting: datasets/cifar10/cifar10/truck/0551.png
#  extracting: datasets/cifar10/cifar10/truck/0552.png
#  extracting: datasets/cifar10/cifar10/truck/0553.png
#  extracting: datasets/cifar10/cifar10/truck/0554.png
#  extracting: datasets/cifar10/cifar10/truck/0555.png
#  extracting: datasets/cifar10/cifar10/truck/0556.png
#  extracting: datasets/cifar10/cifar10/truck/0557.png
#  extracting: datasets/cifar10/cifar10/truck/0558.png
#  extracting: datasets/cifar10/cifar10/truck/0559.png
#  extracting: datasets/cifar10/cifar10/truck/0560.png
#  extracting: datasets/cifar10/cifar10/truck/0561.png
#  extracting: datasets/cifar10/cifar10/truck/0562.png
#  extracting: datasets/cifar10/cifar10/truck/0563.png
#  extracting: datasets/cifar10/cifar10/truck/0564.png
#  extracting: datasets/cifar10/cifar10/truck/0565.png
#  extracting: datasets/cifar10/cifar10/truck/0566.png
#  extracting: datasets/cifar10/cifar10/truck/0567.png
#  extracting: datasets/cifar10/cifar10/truck/0568.png
#  extracting: datasets/cifar10/cifar10/truck/0569.png
#  extracting: datasets/cifar10/cifar10/truck/0570.png
#  extracting: datasets/cifar10/cifar10/truck/0571.png
#  extracting: datasets/cifar10/cifar10/truck/0572.png
#  extracting: datasets/cifar10/cifar10/truck/0573.png
#  extracting: datasets/cifar10/cifar10/truck/0574.png
#  extracting: datasets/cifar10/cifar10/truck/0575.png
#  extracting: datasets/cifar10/cifar10/truck/0576.png
#  extracting: datasets/cifar10/cifar10/truck/0577.png
#  extracting: datasets/cifar10/cifar10/truck/0578.png
#  extracting: datasets/cifar10/cifar10/truck/0579.png
#  extracting: datasets/cifar10/cifar10/truck/0580.png
#  extracting: datasets/cifar10/cifar10/truck/0581.png
#  extracting: datasets/cifar10/cifar10/truck/0582.png
#  extracting: datasets/cifar10/cifar10/truck/0583.png
#  extracting: datasets/cifar10/cifar10/truck/0584.png
#  extracting: datasets/cifar10/cifar10/truck/0585.png
#  extracting: datasets/cifar10/cifar10/truck/0586.png
#  extracting: datasets/cifar10/cifar10/truck/0587.png
#  extracting: datasets/cifar10/cifar10/truck/0588.png
#  extracting: datasets/cifar10/cifar10/truck/0589.png
#  extracting: datasets/cifar10/cifar10/truck/0590.png
#  extracting: datasets/cifar10/cifar10/truck/0591.png
#  extracting: datasets/cifar10/cifar10/truck/0592.png
#  extracting: datasets/cifar10/cifar10/truck/0593.png
#  extracting: datasets/cifar10/cifar10/truck/0594.png
#  extracting: datasets/cifar10/cifar10/truck/0595.png
#  extracting: datasets/cifar10/cifar10/truck/0596.png
#  extracting: datasets/cifar10/cifar10/truck/0597.png
#  extracting: datasets/cifar10/cifar10/truck/0598.png
#  extracting: datasets/cifar10/cifar10/truck/0599.png
#  extracting: datasets/cifar10/cifar10/truck/0600.png
#  extracting: datasets/cifar10/cifar10/truck/0601.png
#  extracting: datasets/cifar10/cifar10/truck/0602.png
#  extracting: datasets/cifar10/cifar10/truck/0603.png
#  extracting: datasets/cifar10/cifar10/truck/0604.png
#  extracting: datasets/cifar10/cifar10/truck/0605.png
#  extracting: datasets/cifar10/cifar10/truck/0606.png
#  extracting: datasets/cifar10/cifar10/truck/0607.png
#  extracting: datasets/cifar10/cifar10/truck/0608.png
#  extracting: datasets/cifar10/cifar10/truck/0609.png
#  extracting: datasets/cifar10/cifar10/truck/0610.png
#  extracting: datasets/cifar10/cifar10/truck/0611.png
#  extracting: datasets/cifar10/cifar10/truck/0612.png
#  extracting: datasets/cifar10/cifar10/truck/0613.png
#  extracting: datasets/cifar10/cifar10/truck/0614.png
#  extracting: datasets/cifar10/cifar10/truck/0615.png
#  extracting: datasets/cifar10/cifar10/truck/0616.png
#  extracting: datasets/cifar10/cifar10/truck/0617.png
#  extracting: datasets/cifar10/cifar10/truck/0618.png
#  extracting: datasets/cifar10/cifar10/truck/0619.png
#  extracting: datasets/cifar10/cifar10/truck/0620.png
#  extracting: datasets/cifar10/cifar10/truck/0621.png
#  extracting: datasets/cifar10/cifar10/truck/0622.png
#  extracting: datasets/cifar10/cifar10/truck/0623.png
#  extracting: datasets/cifar10/cifar10/truck/0624.png
#  extracting: datasets/cifar10/cifar10/truck/0625.png
#  extracting: datasets/cifar10/cifar10/truck/0626.png
#  extracting: datasets/cifar10/cifar10/truck/0627.png
#  extracting: datasets/cifar10/cifar10/truck/0628.png
#  extracting: datasets/cifar10/cifar10/truck/0629.png
#  extracting: datasets/cifar10/cifar10/truck/0630.png
#  extracting: datasets/cifar10/cifar10/truck/0631.png
#  extracting: datasets/cifar10/cifar10/truck/0632.png
#  extracting: datasets/cifar10/cifar10/truck/0633.png
#  extracting: datasets/cifar10/cifar10/truck/0634.png
#  extracting: datasets/cifar10/cifar10/truck/0635.png
#  extracting: datasets/cifar10/cifar10/truck/0636.png
#  extracting: datasets/cifar10/cifar10/truck/0637.png
#  extracting: datasets/cifar10/cifar10/truck/0638.png
#  extracting: datasets/cifar10/cifar10/truck/0639.png
#  extracting: datasets/cifar10/cifar10/truck/0640.png
#  extracting: datasets/cifar10/cifar10/truck/0641.png
#  extracting: datasets/cifar10/cifar10/truck/0642.png
#  extracting: datasets/cifar10/cifar10/truck/0643.png
#  extracting: datasets/cifar10/cifar10/truck/0644.png
#  extracting: datasets/cifar10/cifar10/truck/0645.png
#  extracting: datasets/cifar10/cifar10/truck/0646.png
#  extracting: datasets/cifar10/cifar10/truck/0647.png
#  extracting: datasets/cifar10/cifar10/truck/0648.png
#  extracting: datasets/cifar10/cifar10/truck/0649.png
#  extracting: datasets/cifar10/cifar10/truck/0650.png
#  extracting: datasets/cifar10/cifar10/truck/0651.png
#  extracting: datasets/cifar10/cifar10/truck/0652.png
#  extracting: datasets/cifar10/cifar10/truck/0653.png
#  extracting: datasets/cifar10/cifar10/truck/0654.png
#  extracting: datasets/cifar10/cifar10/truck/0655.png
#  extracting: datasets/cifar10/cifar10/truck/0656.png
#  extracting: datasets/cifar10/cifar10/truck/0657.png
#  extracting: datasets/cifar10/cifar10/truck/0658.png
#  extracting: datasets/cifar10/cifar10/truck/0659.png
#  extracting: datasets/cifar10/cifar10/truck/0660.png
#  extracting: datasets/cifar10/cifar10/truck/0661.png
#  extracting: datasets/cifar10/cifar10/truck/0662.png
#  extracting: datasets/cifar10/cifar10/truck/0663.png
#  extracting: datasets/cifar10/cifar10/truck/0664.png
#  extracting: datasets/cifar10/cifar10/truck/0665.png
#  extracting: datasets/cifar10/cifar10/truck/0666.png
#  extracting: datasets/cifar10/cifar10/truck/0667.png
#  extracting: datasets/cifar10/cifar10/truck/0668.png
#  extracting: datasets/cifar10/cifar10/truck/0669.png
#  extracting: datasets/cifar10/cifar10/truck/0670.png
#  extracting: datasets/cifar10/cifar10/truck/0671.png
#  extracting: datasets/cifar10/cifar10/truck/0672.png
#  extracting: datasets/cifar10/cifar10/truck/0673.png
#  extracting: datasets/cifar10/cifar10/truck/0674.png
#  extracting: datasets/cifar10/cifar10/truck/0675.png
#  extracting: datasets/cifar10/cifar10/truck/0676.png
#  extracting: datasets/cifar10/cifar10/truck/0677.png
#  extracting: datasets/cifar10/cifar10/truck/0678.png
#  extracting: datasets/cifar10/cifar10/truck/0679.png
#  extracting: datasets/cifar10/cifar10/truck/0680.png
#  extracting: datasets/cifar10/cifar10/truck/0681.png
#  extracting: datasets/cifar10/cifar10/truck/0682.png
#  extracting: datasets/cifar10/cifar10/truck/0683.png
#  extracting: datasets/cifar10/cifar10/truck/0684.png
#  extracting: datasets/cifar10/cifar10/truck/0685.png
#  extracting: datasets/cifar10/cifar10/truck/0686.png
#  extracting: datasets/cifar10/cifar10/truck/0687.png
#  extracting: datasets/cifar10/cifar10/truck/0688.png
#  extracting: datasets/cifar10/cifar10/truck/0689.png
#  extracting: datasets/cifar10/cifar10/truck/0690.png
#  extracting: datasets/cifar10/cifar10/truck/0691.png
#  extracting: datasets/cifar10/cifar10/truck/0692.png
#  extracting: datasets/cifar10/cifar10/truck/0693.png
#  extracting: datasets/cifar10/cifar10/truck/0694.png
#  extracting: datasets/cifar10/cifar10/truck/0695.png
#  extracting: datasets/cifar10/cifar10/truck/0696.png
#  extracting: datasets/cifar10/cifar10/truck/0697.png
#  extracting: datasets/cifar10/cifar10/truck/0698.png
#  extracting: datasets/cifar10/cifar10/truck/0699.png
#  extracting: datasets/cifar10/cifar10/truck/0700.png
#  extracting: datasets/cifar10/cifar10/truck/0701.png
#  extracting: datasets/cifar10/cifar10/truck/0702.png
#  extracting: datasets/cifar10/cifar10/truck/0703.png
#  extracting: datasets/cifar10/cifar10/truck/0704.png
#  extracting: datasets/cifar10/cifar10/truck/0705.png
#  extracting: datasets/cifar10/cifar10/truck/0706.png
#  extracting: datasets/cifar10/cifar10/truck/0707.png
#  extracting: datasets/cifar10/cifar10/truck/0708.png
#  extracting: datasets/cifar10/cifar10/truck/0709.png
#  extracting: datasets/cifar10/cifar10/truck/0710.png
#  extracting: datasets/cifar10/cifar10/truck/0711.png
#  extracting: datasets/cifar10/cifar10/truck/0712.png
#  extracting: datasets/cifar10/cifar10/truck/0713.png
#  extracting: datasets/cifar10/cifar10/truck/0714.png
#  extracting: datasets/cifar10/cifar10/truck/0715.png
#  extracting: datasets/cifar10/cifar10/truck/0716.png
#  extracting: datasets/cifar10/cifar10/truck/0717.png
#  extracting: datasets/cifar10/cifar10/truck/0718.png
#  extracting: datasets/cifar10/cifar10/truck/0719.png
#  extracting: datasets/cifar10/cifar10/truck/0720.png
#  extracting: datasets/cifar10/cifar10/truck/0721.png
#  extracting: datasets/cifar10/cifar10/truck/0722.png
#  extracting: datasets/cifar10/cifar10/truck/0723.png
#  extracting: datasets/cifar10/cifar10/truck/0724.png
#  extracting: datasets/cifar10/cifar10/truck/0725.png
#  extracting: datasets/cifar10/cifar10/truck/0726.png
#  extracting: datasets/cifar10/cifar10/truck/0727.png
#  extracting: datasets/cifar10/cifar10/truck/0728.png
#  extracting: datasets/cifar10/cifar10/truck/0729.png
#  extracting: datasets/cifar10/cifar10/truck/0730.png
#  extracting: datasets/cifar10/cifar10/truck/0731.png
#  extracting: datasets/cifar10/cifar10/truck/0732.png
#  extracting: datasets/cifar10/cifar10/truck/0733.png
#  extracting: datasets/cifar10/cifar10/truck/0734.png
#  extracting: datasets/cifar10/cifar10/truck/0735.png
#  extracting: datasets/cifar10/cifar10/truck/0736.png
#  extracting: datasets/cifar10/cifar10/truck/0737.png
#  extracting: datasets/cifar10/cifar10/truck/0738.png
#  extracting: datasets/cifar10/cifar10/truck/0739.png
#  extracting: datasets/cifar10/cifar10/truck/0740.png
#  extracting: datasets/cifar10/cifar10/truck/0741.png
#  extracting: datasets/cifar10/cifar10/truck/0742.png
#  extracting: datasets/cifar10/cifar10/truck/0743.png
#  extracting: datasets/cifar10/cifar10/truck/0744.png
#  extracting: datasets/cifar10/cifar10/truck/0745.png
#  extracting: datasets/cifar10/cifar10/truck/0746.png
#  extracting: datasets/cifar10/cifar10/truck/0747.png
#  extracting: datasets/cifar10/cifar10/truck/0748.png
#  extracting: datasets/cifar10/cifar10/truck/0749.png
#  extracting: datasets/cifar10/cifar10/truck/0750.png
#  extracting: datasets/cifar10/cifar10/truck/0751.png
#  extracting: datasets/cifar10/cifar10/truck/0752.png
#  extracting: datasets/cifar10/cifar10/truck/0753.png
#  extracting: datasets/cifar10/cifar10/truck/0754.png
#  extracting: datasets/cifar10/cifar10/truck/0755.png
#  extracting: datasets/cifar10/cifar10/truck/0756.png
#  extracting: datasets/cifar10/cifar10/truck/0757.png
#  extracting: datasets/cifar10/cifar10/truck/0758.png
#  extracting: datasets/cifar10/cifar10/truck/0759.png
#  extracting: datasets/cifar10/cifar10/truck/0760.png
#  extracting: datasets/cifar10/cifar10/truck/0761.png
#  extracting: datasets/cifar10/cifar10/truck/0762.png
#  extracting: datasets/cifar10/cifar10/truck/0763.png
#  extracting: datasets/cifar10/cifar10/truck/0764.png
#  extracting: datasets/cifar10/cifar10/truck/0765.png
#  extracting: datasets/cifar10/cifar10/truck/0766.png
#  extracting: datasets/cifar10/cifar10/truck/0767.png
#  extracting: datasets/cifar10/cifar10/truck/0768.png
#  extracting: datasets/cifar10/cifar10/truck/0769.png
#  extracting: datasets/cifar10/cifar10/truck/0770.png
#  extracting: datasets/cifar10/cifar10/truck/0771.png
#  extracting: datasets/cifar10/cifar10/truck/0772.png
#  extracting: datasets/cifar10/cifar10/truck/0773.png
#  extracting: datasets/cifar10/cifar10/truck/0774.png
#  extracting: datasets/cifar10/cifar10/truck/0775.png
#  extracting: datasets/cifar10/cifar10/truck/0776.png
#  extracting: datasets/cifar10/cifar10/truck/0777.png
#  extracting: datasets/cifar10/cifar10/truck/0778.png
#  extracting: datasets/cifar10/cifar10/truck/0779.png
#  extracting: datasets/cifar10/cifar10/truck/0780.png
#  extracting: datasets/cifar10/cifar10/truck/0781.png
#  extracting: datasets/cifar10/cifar10/truck/0782.png
#  extracting: datasets/cifar10/cifar10/truck/0783.png
#  extracting: datasets/cifar10/cifar10/truck/0784.png
#  extracting: datasets/cifar10/cifar10/truck/0785.png
#  extracting: datasets/cifar10/cifar10/truck/0786.png
#  extracting: datasets/cifar10/cifar10/truck/0787.png
#  extracting: datasets/cifar10/cifar10/truck/0788.png
#  extracting: datasets/cifar10/cifar10/truck/0789.png
#  extracting: datasets/cifar10/cifar10/truck/0790.png
#  extracting: datasets/cifar10/cifar10/truck/0791.png
#  extracting: datasets/cifar10/cifar10/truck/0792.png
#  extracting: datasets/cifar10/cifar10/truck/0793.png
#  extracting: datasets/cifar10/cifar10/truck/0794.png
#  extracting: datasets/cifar10/cifar10/truck/0795.png
#  extracting: datasets/cifar10/cifar10/truck/0796.png
#  extracting: datasets/cifar10/cifar10/truck/0797.png
#  extracting: datasets/cifar10/cifar10/truck/0798.png
#  extracting: datasets/cifar10/cifar10/truck/0799.png
#  extracting: datasets/cifar10/cifar10/truck/0800.png
#  extracting: datasets/cifar10/cifar10/truck/0801.png
#  extracting: datasets/cifar10/cifar10/truck/0802.png
#  extracting: datasets/cifar10/cifar10/truck/0803.png
#  extracting: datasets/cifar10/cifar10/truck/0804.png
#  extracting: datasets/cifar10/cifar10/truck/0805.png
#  extracting: datasets/cifar10/cifar10/truck/0806.png
#  extracting: datasets/cifar10/cifar10/truck/0807.png
#  extracting: datasets/cifar10/cifar10/truck/0808.png
#  extracting: datasets/cifar10/cifar10/truck/0809.png
#  extracting: datasets/cifar10/cifar10/truck/0810.png
#  extracting: datasets/cifar10/cifar10/truck/0811.png
#  extracting: datasets/cifar10/cifar10/truck/0812.png
#  extracting: datasets/cifar10/cifar10/truck/0813.png
#  extracting: datasets/cifar10/cifar10/truck/0814.png
#  extracting: datasets/cifar10/cifar10/truck/0815.png
#  extracting: datasets/cifar10/cifar10/truck/0816.png
#  extracting: datasets/cifar10/cifar10/truck/0817.png
#  extracting: datasets/cifar10/cifar10/truck/0818.png
#  extracting: datasets/cifar10/cifar10/truck/0819.png
#  extracting: datasets/cifar10/cifar10/truck/0820.png
#  extracting: datasets/cifar10/cifar10/truck/0821.png
#  extracting: datasets/cifar10/cifar10/truck/0822.png
#  extracting: datasets/cifar10/cifar10/truck/0823.png
#  extracting: datasets/cifar10/cifar10/truck/0824.png
#  extracting: datasets/cifar10/cifar10/truck/0825.png
#  extracting: datasets/cifar10/cifar10/truck/0826.png
#  extracting: datasets/cifar10/cifar10/truck/0827.png
#  extracting: datasets/cifar10/cifar10/truck/0828.png
#  extracting: datasets/cifar10/cifar10/truck/0829.png
#  extracting: datasets/cifar10/cifar10/truck/0830.png
#  extracting: datasets/cifar10/cifar10/truck/0831.png
#  extracting: datasets/cifar10/cifar10/truck/0832.png
#  extracting: datasets/cifar10/cifar10/truck/0833.png
#  extracting: datasets/cifar10/cifar10/truck/0834.png
#  extracting: datasets/cifar10/cifar10/truck/0835.png
#  extracting: datasets/cifar10/cifar10/truck/0836.png
#  extracting: datasets/cifar10/cifar10/truck/0837.png
#  extracting: datasets/cifar10/cifar10/truck/0838.png
#  extracting: datasets/cifar10/cifar10/truck/0839.png
#  extracting: datasets/cifar10/cifar10/truck/0840.png
#  extracting: datasets/cifar10/cifar10/truck/0841.png
#  extracting: datasets/cifar10/cifar10/truck/0842.png
#  extracting: datasets/cifar10/cifar10/truck/0843.png
#  extracting: datasets/cifar10/cifar10/truck/0844.png
#  extracting: datasets/cifar10/cifar10/truck/0845.png
#  extracting: datasets/cifar10/cifar10/truck/0846.png
#  extracting: datasets/cifar10/cifar10/truck/0847.png
#  extracting: datasets/cifar10/cifar10/truck/0848.png
#  extracting: datasets/cifar10/cifar10/truck/0849.png
#  extracting: datasets/cifar10/cifar10/truck/0850.png
#  extracting: datasets/cifar10/cifar10/truck/0851.png
#  extracting: datasets/cifar10/cifar10/truck/0852.png
#  extracting: datasets/cifar10/cifar10/truck/0853.png
#  extracting: datasets/cifar10/cifar10/truck/0854.png
#  extracting: datasets/cifar10/cifar10/truck/0855.png
#  extracting: datasets/cifar10/cifar10/truck/0856.png
#  extracting: datasets/cifar10/cifar10/truck/0857.png
#  extracting: datasets/cifar10/cifar10/truck/0858.png
#  extracting: datasets/cifar10/cifar10/truck/0859.png
#  extracting: datasets/cifar10/cifar10/truck/0860.png
#  extracting: datasets/cifar10/cifar10/truck/0861.png
#  extracting: datasets/cifar10/cifar10/truck/0862.png
#  extracting: datasets/cifar10/cifar10/truck/0863.png
#  extracting: datasets/cifar10/cifar10/truck/0864.png
#  extracting: datasets/cifar10/cifar10/truck/0865.png
# ...
#  extracting: datasets/cifar10/cifar10/truck/4704.png
#  extracting: datasets/cifar10/cifar10/truck/4705.png
#  extracting: datasets/cifar10/cifar10/truck/4706.png
#  extracting: datasets/cifar10/cifar10/truck/4707.png
#  extracting: datasets/cifar10/cifar10/truck/4708.png
#  extracting: datasets/cifar10/cifar10/truck/4709.png
#  extracting: datasets/cifar10/cifar10/truck/4710.png
#  extracting: datasets/cifar10/cifar10/truck/4711.png
#  extracting: datasets/cifar10/cifar10/truck/4712.png
#  extracting: datasets/cifar10/cifar10/truck/4713.png
#  extracting: datasets/cifar10/cifar10/truck/4714.png
#  extracting: datasets/cifar10/cifar10/truck/4715.png
#  extracting: datasets/cifar10/cifar10/truck/4716.png
#  extracting: datasets/cifar10/cifar10/truck/4717.png
#  extracting: datasets/cifar10/cifar10/truck/4718.png
#  extracting: datasets/cifar10/cifar10/truck/4719.png
#  extracting: datasets/cifar10/cifar10/truck/4720.png
#  extracting: datasets/cifar10/cifar10/truck/4721.png
#  extracting: datasets/cifar10/cifar10/truck/4722.png
#  extracting: datasets/cifar10/cifar10/truck/4723.png
#  extracting: datasets/cifar10/cifar10/truck/4724.png
#  extracting: datasets/cifar10/cifar10/truck/4725.png
#  extracting: datasets/cifar10/cifar10/truck/4726.png
#  extracting: datasets/cifar10/cifar10/truck/4727.png
#  extracting: datasets/cifar10/cifar10/truck/4728.png
#  extracting: datasets/cifar10/cifar10/truck/4729.png
#  extracting: datasets/cifar10/cifar10/truck/4730.png
#  extracting: datasets/cifar10/cifar10/truck/4731.png
#  extracting: datasets/cifar10/cifar10/truck/4732.png
#  extracting: datasets/cifar10/cifar10/truck/4733.png
#  extracting: datasets/cifar10/cifar10/truck/4734.png
#  extracting: datasets/cifar10/cifar10/truck/4735.png
#  extracting: datasets/cifar10/cifar10/truck/4736.png
#  extracting: datasets/cifar10/cifar10/truck/4737.png
#  extracting: datasets/cifar10/cifar10/truck/4738.png
#  extracting: datasets/cifar10/cifar10/truck/4739.png
#  extracting: datasets/cifar10/cifar10/truck/4740.png
#  extracting: datasets/cifar10/cifar10/truck/4741.png
#  extracting: datasets/cifar10/cifar10/truck/4742.png
#  extracting: datasets/cifar10/cifar10/truck/4743.png
#  extracting: datasets/cifar10/cifar10/truck/4744.png
#  extracting: datasets/cifar10/cifar10/truck/4745.png
#  extracting: datasets/cifar10/cifar10/truck/4746.png
#  extracting: datasets/cifar10/cifar10/truck/4747.png
#  extracting: datasets/cifar10/cifar10/truck/4748.png
#  extracting: datasets/cifar10/cifar10/truck/4749.png
#  extracting: datasets/cifar10/cifar10/truck/4750.png
#  extracting: datasets/cifar10/cifar10/truck/4751.png
#  extracting: datasets/cifar10/cifar10/truck/4752.png
#  extracting: datasets/cifar10/cifar10/truck/4753.png
#  extracting: datasets/cifar10/cifar10/truck/4754.png
#  extracting: datasets/cifar10/cifar10/truck/4755.png
#  extracting: datasets/cifar10/cifar10/truck/4756.png
#  extracting: datasets/cifar10/cifar10/truck/4757.png
#  extracting: datasets/cifar10/cifar10/truck/4758.png
#  extracting: datasets/cifar10/cifar10/truck/4759.png
#  extracting: datasets/cifar10/cifar10/truck/4760.png
#  extracting: datasets/cifar10/cifar10/truck/4761.png
#  extracting: datasets/cifar10/cifar10/truck/4762.png
#  extracting: datasets/cifar10/cifar10/truck/4763.png
#  extracting: datasets/cifar10/cifar10/truck/4764.png
#  extracting: datasets/cifar10/cifar10/truck/4765.png
#  extracting: datasets/cifar10/cifar10/truck/4766.png
#  extracting: datasets/cifar10/cifar10/truck/4767.png
#  extracting: datasets/cifar10/cifar10/truck/4768.png
#  extracting: datasets/cifar10/cifar10/truck/4769.png
#  extracting: datasets/cifar10/cifar10/truck/4770.png
#  extracting: datasets/cifar10/cifar10/truck/4771.png
#  extracting: datasets/cifar10/cifar10/truck/4772.png
#  extracting: datasets/cifar10/cifar10/truck/4773.png
#  extracting: datasets/cifar10/cifar10/truck/4774.png
#  extracting: datasets/cifar10/cifar10/truck/4775.png
#  extracting: datasets/cifar10/cifar10/truck/4776.png
#  extracting: datasets/cifar10/cifar10/truck/4777.png
#  extracting: datasets/cifar10/cifar10/truck/4778.png
#  extracting: datasets/cifar10/cifar10/truck/4779.png
#  extracting: datasets/cifar10/cifar10/truck/4780.png
#  extracting: datasets/cifar10/cifar10/truck/4781.png
#  extracting: datasets/cifar10/cifar10/truck/4782.png
#  extracting: datasets/cifar10/cifar10/truck/4783.png
#  extracting: datasets/cifar10/cifar10/truck/4784.png
#  extracting: datasets/cifar10/cifar10/truck/4785.png
#  extracting: datasets/cifar10/cifar10/truck/4786.png
#  extracting: datasets/cifar10/cifar10/truck/4787.png
#  extracting: datasets/cifar10/cifar10/truck/4788.png
#  extracting: datasets/cifar10/cifar10/truck/4789.png
#  extracting: datasets/cifar10/cifar10/truck/4790.png
#  extracting: datasets/cifar10/cifar10/truck/4791.png
#  extracting: datasets/cifar10/cifar10/truck/4792.png
#  extracting: datasets/cifar10/cifar10/truck/4793.png
#  extracting: datasets/cifar10/cifar10/truck/4794.png
#  extracting: datasets/cifar10/cifar10/truck/4795.png
#  extracting: datasets/cifar10/cifar10/truck/4796.png
#  extracting: datasets/cifar10/cifar10/truck/4797.png
#  extracting: datasets/cifar10/cifar10/truck/4798.png
#  extracting: datasets/cifar10/cifar10/truck/4799.png
#  extracting: datasets/cifar10/cifar10/truck/4800.png
#  extracting: datasets/cifar10/cifar10/truck/4801.png
#  extracting: datasets/cifar10/cifar10/truck/4802.png
#  extracting: datasets/cifar10/cifar10/truck/4803.png
#  extracting: datasets/cifar10/cifar10/truck/4804.png
#  extracting: datasets/cifar10/cifar10/truck/4805.png
#  extracting: datasets/cifar10/cifar10/truck/4806.png
#  extracting: datasets/cifar10/cifar10/truck/4807.png
#  extracting: datasets/cifar10/cifar10/truck/4808.png
#  extracting: datasets/cifar10/cifar10/truck/4809.png
#  extracting: datasets/cifar10/cifar10/truck/4810.png
#  extracting: datasets/cifar10/cifar10/truck/4811.png
#  extracting: datasets/cifar10/cifar10/truck/4812.png
#  extracting: datasets/cifar10/cifar10/truck/4813.png
#  extracting: datasets/cifar10/cifar10/truck/4814.png
#  extracting: datasets/cifar10/cifar10/truck/4815.png
#  extracting: datasets/cifar10/cifar10/truck/4816.png
#  extracting: datasets/cifar10/cifar10/truck/4817.png
#  extracting: datasets/cifar10/cifar10/truck/4818.png
#  extracting: datasets/cifar10/cifar10/truck/4819.png
#  extracting: datasets/cifar10/cifar10/truck/4820.png
#  extracting: datasets/cifar10/cifar10/truck/4821.png
#  extracting: datasets/cifar10/cifar10/truck/4822.png
#  extracting: datasets/cifar10/cifar10/truck/4823.png
#  extracting: datasets/cifar10/cifar10/truck/4824.png
#  extracting: datasets/cifar10/cifar10/truck/4825.png
#  extracting: datasets/cifar10/cifar10/truck/4826.png
#  extracting: datasets/cifar10/cifar10/truck/4827.png
#  extracting: datasets/cifar10/cifar10/truck/4828.png
#  extracting: datasets/cifar10/cifar10/truck/4829.png
#  extracting: datasets/cifar10/cifar10/truck/4830.png
#  extracting: datasets/cifar10/cifar10/truck/4831.png
#  extracting: datasets/cifar10/cifar10/truck/4832.png
#  extracting: datasets/cifar10/cifar10/truck/4833.png
#  extracting: datasets/cifar10/cifar10/truck/4834.png
#  extracting: datasets/cifar10/cifar10/truck/4835.png
#  extracting: datasets/cifar10/cifar10/truck/4836.png
#  extracting: datasets/cifar10/cifar10/truck/4837.png
#  extracting: datasets/cifar10/cifar10/truck/4838.png
#  extracting: datasets/cifar10/cifar10/truck/4839.png
#  extracting: datasets/cifar10/cifar10/truck/4840.png
#  extracting: datasets/cifar10/cifar10/truck/4841.png
#  extracting: datasets/cifar10/cifar10/truck/4842.png
#  extracting: datasets/cifar10/cifar10/truck/4843.png
#  extracting: datasets/cifar10/cifar10/truck/4844.png
#  extracting: datasets/cifar10/cifar10/truck/4845.png
#  extracting: datasets/cifar10/cifar10/truck/4846.png
#  extracting: datasets/cifar10/cifar10/truck/4847.png
#  extracting: datasets/cifar10/cifar10/truck/4848.png
#  extracting: datasets/cifar10/cifar10/truck/4849.png
#  extracting: datasets/cifar10/cifar10/truck/4850.png
#  extracting: datasets/cifar10/cifar10/truck/4851.png
#  extracting: datasets/cifar10/cifar10/truck/4852.png
#  extracting: datasets/cifar10/cifar10/truck/4853.png
#  extracting: datasets/cifar10/cifar10/truck/4854.png
#  extracting: datasets/cifar10/cifar10/truck/4855.png
#  extracting: datasets/cifar10/cifar10/truck/4856.png
#  extracting: datasets/cifar10/cifar10/truck/4857.png
#  extracting: datasets/cifar10/cifar10/truck/4858.png
#  extracting: datasets/cifar10/cifar10/truck/4859.png
#  extracting: datasets/cifar10/cifar10/truck/4860.png
#  extracting: datasets/cifar10/cifar10/truck/4861.png
#  extracting: datasets/cifar10/cifar10/truck/4862.png
#  extracting: datasets/cifar10/cifar10/truck/4863.png
#  extracting: datasets/cifar10/cifar10/truck/4864.png
#  extracting: datasets/cifar10/cifar10/truck/4865.png
#  extracting: datasets/cifar10/cifar10/truck/4866.png
#  extracting: datasets/cifar10/cifar10/truck/4867.png
#  extracting: datasets/cifar10/cifar10/truck/4868.png
#  extracting: datasets/cifar10/cifar10/truck/4869.png
#  extracting: datasets/cifar10/cifar10/truck/4870.png
#  extracting: datasets/cifar10/cifar10/truck/4871.png
#  extracting: datasets/cifar10/cifar10/truck/4872.png
#  extracting: datasets/cifar10/cifar10/truck/4873.png
#  extracting: datasets/cifar10/cifar10/truck/4874.png
#  extracting: datasets/cifar10/cifar10/truck/4875.png
#  extracting: datasets/cifar10/cifar10/truck/4876.png
#  extracting: datasets/cifar10/cifar10/truck/4877.png
#  extracting: datasets/cifar10/cifar10/truck/4878.png
#  extracting: datasets/cifar10/cifar10/truck/4879.png
#  extracting: datasets/cifar10/cifar10/truck/4880.png
#  extracting: datasets/cifar10/cifar10/truck/4881.png
#  extracting: datasets/cifar10/cifar10/truck/4882.png
#  extracting: datasets/cifar10/cifar10/truck/4883.png
#  extracting: datasets/cifar10/cifar10/truck/4884.png
#  extracting: datasets/cifar10/cifar10/truck/4885.png
#  extracting: datasets/cifar10/cifar10/truck/4886.png
#  extracting: datasets/cifar10/cifar10/truck/4887.png
#  extracting: datasets/cifar10/cifar10/truck/4888.png
#  extracting: datasets/cifar10/cifar10/truck/4889.png
#  extracting: datasets/cifar10/cifar10/truck/4890.png
#  extracting: datasets/cifar10/cifar10/truck/4891.png
#  extracting: datasets/cifar10/cifar10/truck/4892.png
#  extracting: datasets/cifar10/cifar10/truck/4893.png
#  extracting: datasets/cifar10/cifar10/truck/4894.png
#  extracting: datasets/cifar10/cifar10/truck/4895.png
#  extracting: datasets/cifar10/cifar10/truck/4896.png
#  extracting: datasets/cifar10/cifar10/truck/4897.png
#  extracting: datasets/cifar10/cifar10/truck/4898.png
#  extracting: datasets/cifar10/cifar10/truck/4899.png
#  extracting: datasets/cifar10/cifar10/truck/4900.png
#  extracting: datasets/cifar10/cifar10/truck/4901.png
#  extracting: datasets/cifar10/cifar10/truck/4902.png
#  extracting: datasets/cifar10/cifar10/truck/4903.png
#  extracting: datasets/cifar10/cifar10/truck/4904.png
#  extracting: datasets/cifar10/cifar10/truck/4905.png
#  extracting: datasets/cifar10/cifar10/truck/4906.png
#  extracting: datasets/cifar10/cifar10/truck/4907.png
#  extracting: datasets/cifar10/cifar10/truck/4908.png
#  extracting: datasets/cifar10/cifar10/truck/4909.png
#  extracting: datasets/cifar10/cifar10/truck/4910.png
#  extracting: datasets/cifar10/cifar10/truck/4911.png
#  extracting: datasets/cifar10/cifar10/truck/4912.png
#  extracting: datasets/cifar10/cifar10/truck/4913.png
#  extracting: datasets/cifar10/cifar10/truck/4914.png
#  extracting: datasets/cifar10/cifar10/truck/4915.png
#  extracting: datasets/cifar10/cifar10/truck/4916.png
#  extracting: datasets/cifar10/cifar10/truck/4917.png
#  extracting: datasets/cifar10/cifar10/truck/4918.png
#  extracting: datasets/cifar10/cifar10/truck/4919.png
#  extracting: datasets/cifar10/cifar10/truck/4920.png
#  extracting: datasets/cifar10/cifar10/truck/4921.png
#  extracting: datasets/cifar10/cifar10/truck/4922.png
#  extracting: datasets/cifar10/cifar10/truck/4923.png
#  extracting: datasets/cifar10/cifar10/truck/4924.png
#  extracting: datasets/cifar10/cifar10/truck/4925.png
#  extracting: datasets/cifar10/cifar10/truck/4926.png
#  extracting: datasets/cifar10/cifar10/truck/4927.png
#  extracting: datasets/cifar10/cifar10/truck/4928.png
#  extracting: datasets/cifar10/cifar10/truck/4929.png
#  extracting: datasets/cifar10/cifar10/truck/4930.png
#  extracting: datasets/cifar10/cifar10/truck/4931.png
#  extracting: datasets/cifar10/cifar10/truck/4932.png
#  extracting: datasets/cifar10/cifar10/truck/4933.png
#  extracting: datasets/cifar10/cifar10/truck/4934.png
#  extracting: datasets/cifar10/cifar10/truck/4935.png
#  extracting: datasets/cifar10/cifar10/truck/4936.png
#  extracting: datasets/cifar10/cifar10/truck/4937.png
#  extracting: datasets/cifar10/cifar10/truck/4938.png
#  extracting: datasets/cifar10/cifar10/truck/4939.png
#  extracting: datasets/cifar10/cifar10/truck/4940.png
#  extracting: datasets/cifar10/cifar10/truck/4941.png
#  extracting: datasets/cifar10/cifar10/truck/4942.png
#  extracting: datasets/cifar10/cifar10/truck/4943.png
#  extracting: datasets/cifar10/cifar10/truck/4944.png
#  extracting: datasets/cifar10/cifar10/truck/4945.png
#  extracting: datasets/cifar10/cifar10/truck/4946.png
#  extracting: datasets/cifar10/cifar10/truck/4947.png
#  extracting: datasets/cifar10/cifar10/truck/4948.png
#  extracting: datasets/cifar10/cifar10/truck/4949.png
#  extracting: datasets/cifar10/cifar10/truck/4950.png
#  extracting: datasets/cifar10/cifar10/truck/4951.png
#  extracting: datasets/cifar10/cifar10/truck/4952.png
#  extracting: datasets/cifar10/cifar10/truck/4953.png
#  extracting: datasets/cifar10/cifar10/truck/4954.png
#  extracting: datasets/cifar10/cifar10/truck/4955.png
#  extracting: datasets/cifar10/cifar10/truck/4956.png
#  extracting: datasets/cifar10/cifar10/truck/4957.png
#  extracting: datasets/cifar10/cifar10/truck/4958.png
#  extracting: datasets/cifar10/cifar10/truck/4959.png
#  extracting: datasets/cifar10/cifar10/truck/4960.png
#  extracting: datasets/cifar10/cifar10/truck/4961.png
#  extracting: datasets/cifar10/cifar10/truck/4962.png
#  extracting: datasets/cifar10/cifar10/truck/4963.png
#  extracting: datasets/cifar10/cifar10/truck/4964.png
#  extracting: datasets/cifar10/cifar10/truck/4965.png
#  extracting: datasets/cifar10/cifar10/truck/4966.png
#  extracting: datasets/cifar10/cifar10/truck/4967.png
#  extracting: datasets/cifar10/cifar10/truck/4968.png
#  extracting: datasets/cifar10/cifar10/truck/4969.png
#  extracting: datasets/cifar10/cifar10/truck/4970.png
#  extracting: datasets/cifar10/cifar10/truck/4971.png
#  extracting: datasets/cifar10/cifar10/truck/4972.png
#  extracting: datasets/cifar10/cifar10/truck/4973.png
#  extracting: datasets/cifar10/cifar10/truck/4974.png
#  extracting: datasets/cifar10/cifar10/truck/4975.png
#  extracting: datasets/cifar10/cifar10/truck/4976.png
#  extracting: datasets/cifar10/cifar10/truck/4977.png
#  extracting: datasets/cifar10/cifar10/truck/4978.png
#  extracting: datasets/cifar10/cifar10/truck/4979.png
#  extracting: datasets/cifar10/cifar10/truck/4980.png
#  extracting: datasets/cifar10/cifar10/truck/4981.png
#  extracting: datasets/cifar10/cifar10/truck/4982.png
#  extracting: datasets/cifar10/cifar10/truck/4983.png
#  extracting: datasets/cifar10/cifar10/truck/4984.png
#   inflating: datasets/cifar10/cifar10/truck/4985.png
#  extracting: datasets/cifar10/cifar10/truck/4986.png
#  extracting: datasets/cifar10/cifar10/truck/4987.png
#  extracting: datasets/cifar10/cifar10/truck/4988.png
#  extracting: datasets/cifar10/cifar10/truck/4989.png
#  extracting: datasets/cifar10/cifar10/truck/4990.png
#  extracting: datasets/cifar10/cifar10/truck/4991.png
#  extracting: datasets/cifar10/cifar10/truck/4992.png
#  extracting: datasets/cifar10/cifar10/truck/4993.png

# %%
download_url = "https://i2dl.vc.in.tum.de/static/data/cifar10.zip"
i2dl_exercises_path = "/content"#os.path.dirname(os.path.abspath(os.getcwd()))
cifar_root = os.path.join(i2dl_exercises_path, "datasets", "cifar10")
# Use the Cifar10 mean and standard deviation computed in Exercise 3.
cifar_mean = np.array([0.49191375, 0.48235852, 0.44673872])
cifar_std  = np.array([0.24706447, 0.24346213, 0.26147554])
# Define all the transforms we will apply on the images when 
# retrieving them.
rescale_transform = RescaleTransform()
normalize_transform = NormalizeTransform(
    mean=cifar_mean,
    std=cifar_std
)
flatten_transform = FlattenTransform()
compose_transform = ComposeTransform([rescale_transform, normalize_transform,
                                      flatten_transform])
# Create a train, validation and test dataset.
datasets = {}
for mode in ['train', 'val', 'test']:
    crt_dataset = ImageFolderDataset(
        mode=mode,
        root=cifar_root, 
        download_url=download_url,
        transform=compose_transform,
        split={'train': 0.6, 'val': 0.2, 'test': 0.2}
    )
    datasets[mode] = crt_dataset

# %% [markdown]
# Then, based on this ```Dataset``` object, we can construct a ```Dataloader``` object which samples a random mini-batch of data at once.

# %%
# Create a dataloader for each split.
dataloaders = {}
for mode in ['train', 'val', 'test']:
    crt_dataloader = DataLoader(
        dataset=datasets[mode],
        batch_size=256,
        shuffle=True,
        drop_last=True,
    )
    dataloaders[mode] = crt_dataloader

# %% [markdown]
# Because the ```Dataloader``` has the ```__iter__()``` method, we can simply iterate through the batches it produces, like this:
#
# ```python
# for batch in dataloader['train']:
#     do_something(batch)
# ```

# %% [markdown]
# ## 1.2 Data Augmentation
#
# After the above preprocessing steps, our data is in a good shape and ready to be fed into our network. As explained in the chapter above, we used the transformation functions `RescaleTransform`, `NormalizeTransform` and `FlattenTransform` to achieve this shape. These are the general steps that you need to perform on the data before we can even start the training. Of course, all these steps have to be applied to all three splits of our dataset (train, val and test split). So in other words, preprocessing involves preparing the data before they are used in training and inference.
#
# Besides these basic transformations, there are many other transformation methods that you can apply to the images. For example, you can <b>flip the images horizontally</b> or <b>blur the image</b> and use these new images to enlarge your dataset. This idea is called Data Augmentation and it involves methods that alter the training images to generate a synthetic dataset that is larger than your original dataset and will hopefully improve the performance of your model. The purpose here is different than in the data preprocessing steps and there is one big difference between data augmentation and data preprocessing: The transformation methods to enlarge your dataset should only be applied to the training data. The validation and test data are not affected by these methods.
#
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p>The choice of transformation methods to use for data augmentation can be seen as a hyperparameter of your model and you can try to include these to enlarge your training data and obtain better results for your model. In <code>exercise_code/data/image_folder_dataset.py</code> we implemented the function <code>RandomHorizontalFlip</code> for you, which is randomly flipping an image. Check out the implementation.</p>
#     <p> Later, we will apply some hyperparameter tuning and in order to improve your model's accuracy, you could try to include some data augmentation methods. Fell free to play around and maybe also implement some other methods as for example Gaussian Blur or Rotation. </p>
# </div>
#
# Let us quickly check out the `RandomHorizontalFlip` method with an image of the Cifar10 dataset in the following cell.

# %%
#Load the data in a dataset without any transformation 
dataset = ImageFolderDataset(
        mode=mode,
        root=cifar_root, 
        download_url=download_url,
        split={'train': 0.6, 'val': 0.2, 'test': 0.2},
    )

#Retrieve an image from the dataset and flip it
image = dataset[1]['image']
transform = RandomHorizontalFlip(1)
image_flipped = transform(image)

#Show the two images
plt.figure(figsize = (2,2))
plt.subplot(1, 2, 1)
plt.imshow(image.astype('uint8'))
plt.axis('off')
plt.subplot(1, 2, 2)
plt.imshow(image_flipped.astype('uint8'))
plt.axis('off')
plt.title("Left: Original Image, Right: Flipped image")
plt.show()

# %% [markdown]
# ## 1.3 Layers
#
# Now, that the data is prepared, we can discuss the model in which we are feeding the data. In our case the model will be a neural network.
#
# In Exercise 5, you implemented a simple 2-layer neural network that had a hidden size as a parameter:
#
# $$
# {\hat{y}} = \sigma(\sigma({x W_1} + {b_1}) {W_2} + {b_2})
# $$
#
# where $ \sigma({x}) $ was the sigmoid function, $ {x} $ was the input, $ {W_1}, {W_2} $ the weight matrices and $ {b_1}, {b_2}$ the biases for the two layers.
#
# This is how we used this network:

# %%
input_size = datasets['train'][0]['image'].shape[0]
model = ClassificationNet(input_size=input_size, hidden_size=512)

# %% [markdown]
# Note that we updated the ```ClassificationNet``` from the previous exercise, so that now you can customize more: the number of outputs, the choice of activation function, the hidden size etc. We encourage you to check out the implementation in ```exercise_code/networks/classification_net.py```

# %%
num_layer = 2
reg = 0.1

model = ClassificationNet(activation=Sigmoid(), num_layer=num_layer, reg=reg,
                          num_classes=10)

# %% [markdown]
# Then, the forward and backward passes through the model were simply:
#
# ```python
#
# # X is a batch of training features
# # X.shape = (batch_size, features_size)
# y_out = model.forward(X)
#
# # dout is the gradient of the loss function w.r.t the output of the network.
# # dout.shape = (batch_size, )
# model.backward(dout)
# ```

# %% [markdown]
# Just as the learning rate or the number of iterations we want to train for, the number of hidden layers and the number of units in each hidden layer are also hyperparameters. In this notebook you will play with networks of different sizes and will see the impact that the network capacity has.
#
# Before we move on to the loss functions, we want to have a look at the activation functions. The choice of an activation function can have a huge impact on the performance of the network that you are designing. So far, you have implemented the `Sigmoid` and the `Relu` activation function in Exercise 5.
#
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p>Take a look at the <code>Sigmoid</code> and the <code>Relu</code> class in <code>exercise_code/networks/layer.py</code> and the implementation of the respective forward and backward pass. Make sure to understand why we use <b>element-wise product</b> instead of dot product in the backward pass of the <code>Sigmoid</code> class to compute the gradient $dx$. That will be helpful for your later implementation of other activation functions.</p>
#     <p> <b>Note:</b> The <code>cache</code> variable is used to store information from the forward pass and then pass this information in the backward pass to make use of it there. The implementation of both classes show that this variable can be used differently - depending on what information is needed in the backward pass. </p>
# </div>
#
# Now, we want to have a look at two other, very common activation functions that you have already met in the lecture: Leaky ReLU activation function and Tanh activation function.
#
# **Leaky Relus** are one attempt to fix the “dying ReLU” problem. Instead of the function being zero when $x<0$, a leaky ReLU has a small negative slope (for example, 0.01). That is, the function computes $f(x) = \mathbb{1}(x < 0) (\alpha x) + \mathbb{1}(x>=0) (x)$ where $\alpha$ is a small constant. Some people report success with this form of activation function, but the results are not always consistent.
#
# The **tanh non-linearity** squashes a real-valued number to the range [-1, 1]. Like the sigmoid neuron, its activations saturate, but unlike the sigmoid neuron its output is zero-centered. Therefore, in practice the tanh non-linearity is always preferred to the sigmoid non-linearity. Also note that the tanh neuron is simply a scaled sigmoid neuron, in particular the following holds: $\tanh(x) = 2 \cdot \sigma(2x) -1$.
#
# <img class=left src=https://pytorch.org/docs/stable/_images/LeakyReLU.png alt="Figure3" width="350" align='left'/>
# <img class=right src=https://pytorch.org/docs/stable/_images/Tanh.png alt="Figure4" width="350"/>
#
# <div class="alert alert-info">
#     <h3>Task: Implement Activation Layers</h3>
#     <p> Now, it is your turn to implement the <code>LeakyRelu</code> and the <code>Tanh</code> class in <code>exercise_code/networks/layer.py</code> by completing the <code>forward</code> and the <code>backward</code> functions. You can test your implementation in the following two cells. </p>
#     <p> <b>Note:</b> Always remember to return a cache in <code>forward</code> for later backpropagation in <code>backward</code>. As we have seen above, the <code>cache</code> variable can be used differently for two activation functions.</p>
# </div>
#
# Use this cell to test your implementation of the `LeakyRelu` class:

# %%
from exercise_code.tests.layer_tests import *
print(LeakyReluTestWrapper()())
# Out:
# LeakyReluForwardTest passed.
# LeakyReluBackwardTest passed.
# Congratulations you have passed all the unit tests!!! Tests passed: 2/2
# Score: 100/100
# You secured a score of :100

# %% [markdown]
# And this cell to test your implementation of the `Tanh` class:

# %%
print(TanhTestWrapper()())
# Out:
# TanhForwardTest passed.
# TanhBackwardTest passed.
# Congratulations you have passed all the unit tests!!! Tests passed: 2/2
# Score: 100/100
# You secured a score of :100

# %% [markdown]
# Congratulations, you now implemented all four different activation functions! These activation layers are now ready to be used when you start building your own network.

# %% [markdown]
# ## 1.4 Loss
#
# In order to measure how well a network is performing, we implemented several ```Loss``` classes (```L1```, ```MSE```, ```BCE```, each preferred for a certain type of problems) in ```exercise_code/networks/loss.py```.
#
# Each implemented a ```forward()``` method, which outputs a number that we use as a proxy for our network performance.
#
# Also, because our goal was to change the weights of the network such that this loss measure decreases, we were also interested in the gradients of the loss w.r.t the outputs of the network, $ \nabla_{\hat{y}} L({\hat{y}}, {y}) $. This was implemented in ```backward()```.
#
# In previous exercises, we only worked with binary classification and used binary cross entropy (```BCE```) as a loss function.
#
# $$ BCE(\hat{y}, y) = \frac{1}{N} \sum_{i=1}^N \Big [-y_i \log(\hat{y_i}) - (1-y_i) \log(1 - \hat{y_i}) \Big] $$
#
# where
# - $ N $ was the number of samples we were considering
# - $\hat{y}_i$ was the network's prediction for sample $i$. Note that this was a valid probability $\in [0, 1]$, because we applied a [sigmoid](https://en.wikipedia.org/wiki/Sigmoid_function) activation on the last layer.
# - $ y_i $ was the ground truth label (0 or 1, depending on the class)
#
# Because we have 10 classes in the CIFAR10 dataset, we need a generalization of the binary cross entropy for multiple classes. This is simply called the cross entropy loss and has the following definition:
#
# $$ CE(\hat{y}, y) = \frac{1}{N} \sum_{i=1}^N \sum_{k=1}^{C} \Big[ -y_{ik} \log(\hat{y}_{ik}) \Big] $$
#
# where:
# - $ N $ is again the number of samples
# - $ C $ is the number of classes
# - $ \hat{y}_{ik} $ is the probability that the model assigns for the $k$th class when the $i$th sample is the input. **Because we don't apply any activation function on the last layer of our network, its outputs for each sample will not be a valid probability distribution over the classes. We call these raw outputs of the network '[logits](https://datascience.stackexchange.com/questions/31041/what-does-logits-in-machine-learning-mean/31045)' and we will apply a [softmax](https://en.wikipedia.org/wiki/Softmax_function) activation in order to obtain a valid probability distribution.**
# - $y_{ik} = 1 $ iff the true label of the $i$th sample is $k$ and 0 otherwise. This is called a [one-hot encoding](https://machinelearningmastery.com/why-one-hot-encode-data-in-machine-learning/).
#
# You can check for yourself that when the number of classes $ C $ is 2, then the binary cross entropy is actually equivalent to the cross entropy.
#
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p>Please check the implementation of the <code>CrossEntropyFromLogits</code> class, which can be found in <code>../exercise_06/exercise_code/networks/loss.py</code>. </p>
# </div>

# %%
loss = CrossEntropyFromLogits()

# %% [markdown]
# Just as with the previous losses we have seen, we can simply get the results of the forward and backward passes as follows:

# %% [markdown]
# ```python
# # y_out is the output of the neural network
# # y_truth is the actual label from the dataset
# loss.forward(y_out, y_truth)
# loss.backward(y_out, y_truth)
# ```

# %% [markdown]
# ## 1.5 Optimizer
#
# Now, knowing the gradient of the loss w.r.t the ouputs of the network, as well as the local gradient for each layer of the network, we can use the chain rule to compute all gradients.
#
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p>We implemented several optimizer classes <code>SGD</code>, <code>Adam</code>, <code>sgd_momentum</code> class that implement different first-order parameter update rules, which can be found in <code>../exercise_06/exercise_code/networks/optimizer.py</code>. </p>
#     <p>The <code>step()</code> method iterates through all the parameters of a model and updates them using the gradient information.</p>
# </div>
#
# What the optimizer is doing, in pseudocode, is the following:
#
# ```python
# for param in model:
#     # Use the gradient to update the weights.
#     update(param)
#
#     # Reset the gradient after each update.
#     param.gradient = 0
# ```
#
# ```SGD``` had the simplest update rule:
# ```python
# def update(param):
#     param = param - learning_rate * param.gradient
# ```
#
# For the more complicated update rules, see ```exercise_code/networks/optimizer.py```

# %% [markdown]
# ## 1.6 Solver
#
# The ```Solver``` is where all the above elements come together: Given a train and a validation dataloader, a model, a loss and an optimizer, it uses the training data to optimize a model in order to get better predictions. We simply call ```train()``` and it does its 'magic' for us!
# ```python
# solver = Solver(model,
#                 dataloaders['train'],
#                 dataloaders['val'],
#                 learning_rate=0.001,
#                 loss_func=MSE(),
#                 optimizer=SGD)
#
# solver.train(epochs=epochs)
# ```
#
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p>Please check out the implementation of <code>train()</code> in <code>../exercise_06/exercise_code/solver.py</code>. </p>
# </div>

# %% [markdown]
# ## 1.7 Weight Regularization
#
# Before we finish this section of recap, we want to take a look at some regularization method that has been introduced in the lecture and that is super helpful to improve robustness of our model. Here, we talk about weight regularization.
#
# Weight regularization has been introduced to you as a method preventing our model from overfitting. Essentially, it is a term (solely depending on the weights of our model) that is added to the final loss and that encodes some preference for a certain set of weights $W$ over others. In the lecture, we compared two weight regularization methods and their respective preference for weight vectors. We made the following observation:
#
# 1. L1 regularization: Enforces sparsity
# 2. L2 regularization: Enforces that weights have similar values
#
# The most common weight regularization method is the L2 regularization. From the observations made in the lecture that makes totally sense - at least when we compare it to the L1 regularization. The L2 regularization penalty in the loss prefers smaller and more diffuse weight vectors and hence the model is encouraged to take into account all input dimensions to small amounts rather than a few input dimensions and very strongly.
#
# When using weight regularization, the loss function is a composition of two parts:
# $$L = \underbrace{\frac{1}{N} \sum_{i} L_i}_{\text{data loss}}  + \underbrace{\lambda R(W)}_{\text{regularization loss}}$$
# The first one being the data loss, which is calculated with the Cross Entropy loss in our model. The second part is called the regularization loss $R(W)$ and is computed in the L2 case as follows:
# $$R(W) = \sum_{k} \sum_{l} w_{k,l}^2$$

# %% [markdown]
# # 2. An overview of hyperparameters

# %% [markdown]
# <img src=https://images.deepai.org/glossary-terms/05c646fe1676490aa0b8cab0732a02b2/hyperparams.png alt=hyperparameter width=700>
#
# A **hyperparameter** is a parameter that is set before the learning process begins. Recall that the parameters of weight matrix and bias vector are learned during the learning process.
#
# The hyperparameters are essential, for they control and affect the whole training and have a great impact on the performance of the model.
#
# Some examples of hyperparameters we have covered in lectures:
# * Network architecture
#     * Choice of activation function
#     * Number of layers
#     * ...
# * Learning rate
# * Number of epochs
# * Batch size
# * Regularization strength
# * Momentum
# * ...

# %% [markdown]
# ## 2.1 Start debugging your own network!

# %% [markdown]
# As already suggested in the lectures, you may always want to start from small and simple architectures, to make sure you are going the right way.
#
# First you may need to overfit a single training sample, then a few batches of training samples, then go deeper with larger neural networks and the whole training data.
#
# Here we always provide a default neural network (i.e. ClassificationNet) with arbitrary number of layers, which is a generalization from a fixed 2-layer neural network in exercise 5. You are welcome to implement your own network, in that case just implement **MyOwnNetwork** in ```exercise_code/networks/classification_net.py```. You can also copy things from ClassficationNet and make a little adjustment to your own network. For either way, just pick a network and comment out the other one, then run the cells below for debugging.
#
# <div class="alert alert-warning">
#     <h3>Note:</h3>
#     <p>Please, make sure you don't modify the ClassificationNet itself so that you can always have a working network to fall back on</p>
#     <p>In order to pass this submissions, you can <b>first stick to the default ClassificationNet implementation without changing any code at all</b>. The goal of this submission is to find reasonable hyperparameters and the parameter options of the ClassificationNet are broad enough.</p>
#     <p>Once you have surpassed the submission goal, you can try to implement additional activation functions in the accompanying notebook, try different weight initializations or other adjustments by writing your own network architecture in the MyOwnNetwork class.</p>
# </div>

# %% [markdown]
# First, let's begin with a 2-layer neural network, and overfit one single training sample.
#
# After training, let's evaluate the training process by plotting the loss curves.

# %%
from exercise_code.solver import Solver
from exercise_code.networks.optimizer import SGD, Adam
from exercise_code.networks import MyOwnNetwork

num_layer = 2
epochs = 20
reg = 0.1
batch_size = 4

model = ClassificationNet(num_layer=num_layer, reg=reg)
# model = MyOwnNetwork()

loss = CrossEntropyFromLogits()

# Make a new data loader with a single training image
overfit_dataset = ImageFolderDataset(
    mode='train',
    root=cifar_root, 
    download_url=download_url,
    transform=compose_transform,
    limit_files=1
)
dataloaders['train_overfit_single_image'] = DataLoader(
    dataset=overfit_dataset,
    batch_size=batch_size,
    shuffle=True,
    drop_last=False,
)

# Decrease validation data for only debugging
debugging_validation_dataset = ImageFolderDataset(
    mode='val',
    root=cifar_root, 
    download_url=download_url,
    transform=compose_transform,
    limit_files=100
)
dataloaders['val_500files'] = DataLoader(
    dataset=debugging_validation_dataset,
    batch_size=batch_size,
    shuffle=True,
    drop_last=True,
)

solver = Solver(model, dataloaders['train_overfit_single_image'], dataloaders['val_500files'], 
                learning_rate=1e-3, loss_func=loss, optimizer=Adam)

solver.train(epochs=epochs)
# Out:
# (Epoch 1 / 20) train loss: 2.332700; val loss: 2.332610
# (Epoch 2 / 20) train loss: 2.332700; val loss: 2.228868
# (Epoch 3 / 20) train loss: 2.203055; val loss: 2.149773
# (Epoch 4 / 20) train loss: 2.064933; val loss: 2.085570
# (Epoch 5 / 20) train loss: 1.912125; val loss: 2.026255
# (Epoch 6 / 20) train loss: 1.749965; val loss: 1.965884
# (Epoch 7 / 20) train loss: 1.589484; val loss: 1.901475
# (Epoch 8 / 20) train loss: 1.438696; val loss: 1.832160
# (Epoch 9 / 20) train loss: 1.298190; val loss: 1.759259
# (Epoch 10 / 20) train loss: 1.168201; val loss: 1.685306
# (Epoch 11 / 20) train loss: 1.046968; val loss: 1.612674
# (Epoch 12 / 20) train loss: 0.932562; val loss: 1.542796
# (Epoch 13 / 20) train loss: 0.826371; val loss: 1.475960
# (Epoch 14 / 20) train loss: 0.730257; val loss: 1.411596
# (Epoch 15 / 20) train loss: 0.645018; val loss: 1.348939
# (Epoch 16 / 20) train loss: 0.570640; val loss: 1.287633
# (Epoch 17 / 20) train loss: 0.506418; val loss: 1.227941
# (Epoch 18 / 20) train loss: 0.451238; val loss: 1.170673
# (Epoch 19 / 20) train loss: 0.404122; val loss: 1.116988
# (Epoch 20 / 20) train loss: 0.364245; val loss: 1.068087

# %%
plt.title('Loss curves')
plt.plot(solver.train_loss_history, '-', label='train')
plt.plot(solver.val_loss_history, '-', label='val')
plt.legend(loc='lower right')
plt.xlabel('Iteration')
plt.show()

# %%
print("Training accuray: %.5f" % (solver.get_dataset_accuracy(dataloaders['train_overfit_single_image'])))
print("Validation accuray: %.5f" % (solver.get_dataset_accuracy(dataloaders['val_500files'])))
# Out:
# Training accuray: 1.00000
# Validation accuray: 1.00000

# %% [markdown]
# This time let's try to overfit to a small set of training batch samples. Please observe the difference from above.

# %%
from exercise_code.networks import MyOwnNetwork

num_layer = 2
epochs = 100
reg = 0.1
num_samples = 10

model = ClassificationNet(num_layer=num_layer, reg=reg)
# model = MyOwnNetwork()

loss = CrossEntropyFromLogits()

# Make a new data loader with a our num_samples training image
overfit_dataset = ImageFolderDataset(
    mode='train',
    root=cifar_root, 
    download_url=download_url,
    transform=compose_transform,
    limit_files=num_samples
)
dataloaders['train_overfit_10samples'] = DataLoader(
    dataset=overfit_dataset,
    batch_size=batch_size,
    shuffle=True,
    drop_last=False,
)

solver = Solver(model, dataloaders['train_overfit_10samples'], dataloaders['val_500files'], 
                learning_rate=1e-3, loss_func=loss, optimizer=Adam)

solver.train(epochs=epochs)
# Out:
# (Epoch 1 / 100) train loss: 2.336093; val loss: 2.336116
# (Epoch 2 / 100) train loss: 2.247418; val loss: 2.047715
# (Epoch 3 / 100) train loss: 1.879394; val loss: 1.839438
# (Epoch 4 / 100) train loss: 1.571930; val loss: 1.679094
# (Epoch 5 / 100) train loss: 1.326215; val loss: 1.482069
# (Epoch 6 / 100) train loss: 0.883441; val loss: 1.348389
# (Epoch 7 / 100) train loss: 0.651021; val loss: 1.241712
# (Epoch 8 / 100) train loss: 0.541063; val loss: 1.094046
# (Epoch 9 / 100) train loss: 0.431209; val loss: 0.903114
# (Epoch 10 / 100) train loss: 0.378070; val loss: 0.751383
# (Epoch 11 / 100) train loss: 0.302757; val loss: 0.721785
# (Epoch 12 / 100) train loss: 0.298703; val loss: 0.656189
# (Epoch 13 / 100) train loss: 0.271432; val loss: 0.567956
# (Epoch 14 / 100) train loss: 0.258163; val loss: 0.539284
# (Epoch 15 / 100) train loss: 0.249078; val loss: 0.554624
# (Epoch 16 / 100) train loss: 0.267714; val loss: 0.588475
# (Epoch 17 / 100) train loss: 0.222147; val loss: 0.517042
# (Epoch 18 / 100) train loss: 0.230447; val loss: 0.491534
# (Epoch 19 / 100) train loss: 0.227943; val loss: 0.513489
# (Epoch 20 / 100) train loss: 0.243093; val loss: 0.484736
# (Epoch 21 / 100) train loss: 0.202310; val loss: 0.412170
# (Epoch 22 / 100) train loss: 0.240109; val loss: 0.407020
# (Epoch 23 / 100) train loss: 0.215770; val loss: 0.499581
# (Epoch 24 / 100) train loss: 0.232818; val loss: 0.513769
# (Epoch 25 / 100) train loss: 0.210126; val loss: 0.446017
# (Epoch 26 / 100) train loss: 0.209926; val loss: 0.402775
# (Epoch 27 / 100) train loss: 0.197977; val loss: 0.407251
# (Epoch 28 / 100) train loss: 0.191828; val loss: 0.429304
# (Epoch 29 / 100) train loss: 0.211895; val loss: 0.400815
# (Epoch 30 / 100) train loss: 0.184051; val loss: 0.404045
# (Epoch 31 / 100) train loss: 0.186589; val loss: 0.417686
# (Epoch 32 / 100) train loss: 0.188415; val loss: 0.410093
# (Epoch 33 / 100) train loss: 0.184956; val loss: 0.385965
# (Epoch 34 / 100) train loss: 0.188861; val loss: 0.358552
# (Epoch 35 / 100) train loss: 0.179390; val loss: 0.377039
# (Epoch 36 / 100) train loss: 0.174399; val loss: 0.372026
# (Epoch 37 / 100) train loss: 0.169535; val loss: 0.356125
# (Epoch 38 / 100) train loss: 0.171862; val loss: 0.346214
# (Epoch 39 / 100) train loss: 0.164062; val loss: 0.339009
# (Epoch 40 / 100) train loss: 0.168859; val loss: 0.335432
# (Epoch 41 / 100) train loss: 0.175569; val loss: 0.347999
# (Epoch 42 / 100) train loss: 0.172326; val loss: 0.387150
# (Epoch 43 / 100) train loss: 0.164562; val loss: 0.342870
# (Epoch 44 / 100) train loss: 0.163124; val loss: 0.340768
# (Epoch 45 / 100) train loss: 0.165661; val loss: 0.341322
# (Epoch 46 / 100) train loss: 0.163801; val loss: 0.355554
# (Epoch 47 / 100) train loss: 0.160771; val loss: 0.318423
# (Epoch 48 / 100) train loss: 0.150932; val loss: 0.301242
# (Epoch 49 / 100) train loss: 0.156079; val loss: 0.299830
# (Epoch 50 / 100) train loss: 0.147700; val loss: 0.328344
# (Epoch 51 / 100) train loss: 0.184788; val loss: 0.298431
# (Epoch 52 / 100) train loss: 0.172503; val loss: 0.307329
# (Epoch 53 / 100) train loss: 0.204238; val loss: 0.357418
# (Epoch 54 / 100) train loss: 0.180171; val loss: 0.444180
# (Epoch 55 / 100) train loss: 0.176344; val loss: 0.440050
# (Epoch 56 / 100) train loss: 0.165192; val loss: 0.314743
# (Epoch 57 / 100) train loss: 0.144982; val loss: 0.258304
# (Epoch 58 / 100) train loss: 0.153876; val loss: 0.249561
# (Epoch 59 / 100) train loss: 0.159992; val loss: 0.274856
# (Epoch 60 / 100) train loss: 0.161339; val loss: 0.345910
# (Epoch 61 / 100) train loss: 0.150339; val loss: 0.322037
# (Epoch 62 / 100) train loss: 0.147784; val loss: 0.308120
# (Epoch 63 / 100) train loss: 0.146664; val loss: 0.287973
# (Epoch 64 / 100) train loss: 0.139086; val loss: 0.259194
# (Epoch 65 / 100) train loss: 0.135304; val loss: 0.255430
# (Epoch 66 / 100) train loss: 0.143778; val loss: 0.243634
# (Epoch 67 / 100) train loss: 0.133580; val loss: 0.234144
# (Epoch 68 / 100) train loss: 0.144490; val loss: 0.262922
# (Epoch 69 / 100) train loss: 0.132547; val loss: 0.310311
# (Epoch 70 / 100) train loss: 0.130759; val loss: 0.319563
# (Epoch 71 / 100) train loss: 0.142089; val loss: 0.254514
# (Epoch 72 / 100) train loss: 0.127853; val loss: 0.228349
# (Epoch 73 / 100) train loss: 0.148554; val loss: 0.230821
# (Epoch 74 / 100) train loss: 0.127946; val loss: 0.280615
# (Epoch 75 / 100) train loss: 0.129241; val loss: 0.282056
# (Epoch 76 / 100) train loss: 0.126288; val loss: 0.233290
# (Epoch 77 / 100) train loss: 0.119554; val loss: 0.216694
# (Epoch 78 / 100) train loss: 0.122047; val loss: 0.224178
# (Epoch 79 / 100) train loss: 0.122801; val loss: 0.233207
# (Epoch 80 / 100) train loss: 0.120592; val loss: 0.219442
# (Epoch 81 / 100) train loss: 0.121633; val loss: 0.208982
# (Epoch 82 / 100) train loss: 0.126739; val loss: 0.222873
# (Epoch 83 / 100) train loss: 0.119789; val loss: 0.286715
# (Epoch 84 / 100) train loss: 0.150717; val loss: 0.240650
# (Epoch 85 / 100) train loss: 0.144730; val loss: 0.232384
# (Epoch 86 / 100) train loss: 0.150487; val loss: 0.269429
# (Epoch 87 / 100) train loss: 0.147881; val loss: 0.340871
# (Epoch 88 / 100) train loss: 0.142086; val loss: 0.322404
# (Epoch 89 / 100) train loss: 0.131604; val loss: 0.237587
# (Epoch 90 / 100) train loss: 0.116261; val loss: 0.188009
# (Epoch 91 / 100) train loss: 0.117395; val loss: 0.191673
# (Epoch 92 / 100) train loss: 0.145105; val loss: 0.189228
# (Epoch 93 / 100) train loss: 0.132986; val loss: 0.205543
# (Epoch 94 / 100) train loss: 0.135767; val loss: 0.269206
# (Epoch 95 / 100) train loss: 0.142973; val loss: 0.327068
# (Epoch 96 / 100) train loss: 0.148534; val loss: 0.275935
# (Epoch 97 / 100) train loss: 0.121795; val loss: 0.207633
# (Epoch 98 / 100) train loss: 0.116597; val loss: 0.184701
# (Epoch 99 / 100) train loss: 0.111668; val loss: 0.189769
# (Epoch 100 / 100) train loss: 0.130887; val loss: 0.184746

# %%
plt.title('Loss curves')
plt.plot(solver.train_loss_history, '-', label='train')
plt.plot(solver.val_loss_history, '-', label='val')
plt.legend(loc='lower right')
plt.xlabel('Iteration')
plt.show()

# %%
print("Training accuray: %.5f" % (solver.get_dataset_accuracy(dataloaders['train_overfit_10samples'])))
print("Validation accuray: %.5f" % (solver.get_dataset_accuracy(dataloaders['val_500files'])))
# Out:
# Training accuray: 1.00000
# Validation accuray: 1.00000

# %% [markdown]
# If you're overfitting the training data, that means the network's implementation is correct. However, as you have more samples to overfit, your accuracy will be way lower. You can increase the number of epochs above to achieve better results.
#
# Now let's try to feed all the training and validation data into the network, but this time we set the same hyperparameters for 2-layer and 5-layer networks, and compare the different behaviors.
#
# <div class="alert alert-warning">
#     <h3>Note:</h3>
#     <p>This may take about 1 min for each epoch as the training set is quite large. For convenience, we only train on 1000 images for now but use the full validation set.</p>
# </div>

# %%
from exercise_code.networks import MyOwnNetwork

num_layer = 2
epochs = 5
reg = 0.01

# Make a new data loader with 1000 training samples
num_samples = 1000
overfit_dataset = ImageFolderDataset(
    mode='train',
    root=cifar_root, 
    download_url=download_url,
    transform=compose_transform,
    limit_files=num_samples
)
dataloaders['train_small'] = DataLoader(
    dataset=overfit_dataset,
    batch_size=batch_size,
    shuffle=True,
    drop_last=False,
)


# Change here if you want to use the full training set
use_full_training_set = False
if not use_full_training_set:
    train_loader = dataloaders['train_small']
else:
    train_loader = dataloaders['train']
    

model = ClassificationNet(num_layer=num_layer, reg=reg)
# model = MyOwnNetwork()

loss = CrossEntropyFromLogits()

solver = Solver(model, train_loader, dataloaders['val'], 
                learning_rate=1e-3, loss_func=loss, optimizer=Adam)

solver.train(epochs=epochs)
# Out:
# (Epoch 1 / 5) train loss: 2.304433; val loss: 2.304426
# (Epoch 2 / 5) train loss: 0.285010; val loss: 0.057183
# (Epoch 3 / 5) train loss: 0.053471; val loss: 0.039206
# (Epoch 4 / 5) train loss: 0.061442; val loss: 0.029374
# (Epoch 5 / 5) train loss: 0.025171; val loss: 0.021555

# %%
plt.title('Loss curves')
plt.plot(solver.train_loss_history, '-', label='train')
plt.plot(solver.val_loss_history, '-', label='val')
plt.legend(loc='lower right')
plt.xlabel('Iteration')
plt.show()

# %%
print("Training accuray: %.5f" % (solver.get_dataset_accuracy(train_loader)))
print("Validation accuray: %.5f" % (solver.get_dataset_accuracy(dataloaders['val'])))
# Out:
# Training accuray: 1.00000
# Validation accuray: 1.00000

# %%
from exercise_code.networks import MyOwnNetwork

num_layer = 5
epochs = 5
reg = 0.01

model = ClassificationNet(num_layer=num_layer, reg=reg)
# model = MyOwnNetwork()

# Change here if you want to use the full training set
use_full_training_set = False
if not use_full_training_set:
    train_loader = dataloaders['train_small']
else:
    train_loader = dataloaders['train']

loss = CrossEntropyFromLogits()

solver = Solver(model, train_loader, dataloaders['val'], 
                learning_rate=1e-3, loss_func=loss, optimizer=Adam)

solver.train(epochs=epochs)
# Out:
# (Epoch 1 / 5) train loss: 2.311444; val loss: 2.311444
# (Epoch 2 / 5) train loss: 0.182806; val loss: 0.043827
# (Epoch 3 / 5) train loss: 0.037280; val loss: 0.032135
# (Epoch 4 / 5) train loss: 0.028335; val loss: 0.024993
# (Epoch 5 / 5) train loss: 0.022594; val loss: 0.020585

# %%
plt.title('Loss curves')
plt.plot(solver.train_loss_history, '-', label='train')
plt.plot(solver.val_loss_history, '-', label='val')
plt.legend(loc='lower right')
plt.xlabel('Iteration')
plt.show()

# %%
print("Training accuray: %.5f" % (solver.get_dataset_accuracy(train_loader)))
print("Validation accuray: %.5f" % (solver.get_dataset_accuracy(dataloaders['val'])))
# Out:
# Training accuray: 1.00000
# Validation accuray: 1.00000

# %% [markdown]
# As you can see from above, the same hyperparameter set can decrease the loss for a 2-layer network, but for 5-layer network, it hardly works.
#
# The steps above are already mentioned in the lectures as debugging steps before training a neural network.
#
# If you implement your own network, make sure you do the steps above before tuning the hyperparameters as below.

# %% [markdown]
# ## 2.2 Difficulty in tuning hyperparameters
# As can be seen through the results of training a larger network, training with whole data doesn't fit the training data as well as training with small number of training data. Besides, the architecture of neural network makes a difference, too. Small decisions on hyperparameters count.
#
# Usually, but not always, hyperparameters cannot be learned using well known gradient based methods (such as gradient descent), which are commonly employed to learn parameters. Besides, some hyperparameters can affect the structure of the model and the loss function.
#
# As mentioned before, hyperparameters need to be set before training. Tuning hyperparameters is hard, because you always have to try different combinations of the hyperparameters, train the network, do the validation and pick the best one. Besides, it is not guaranteed that you'll find the best combination.
#
# Next you will do hands on learning with hyperparameter tuning methods that are covered in lectures.

# %% [markdown]
# # 3. Hyperparameter Tuning
#
# ![alt text](https://blog.floydhub.com/content/images/2018/08/Screen-Shot-2018-08-22-at-17.59.25.png "")
#
# One of the main challenges in deep learning is finding the set of hyperparameters that performs best.
#
# So far, we have followed a manual approach by guessing hyperparameters, running the model, observing the result and maybe tweaking the hyperparameters based on this result. As you have probably noticed, this manual hyperparameter tuning is unstructured, inefficient and can become very tedious.
#
#
# A more systematic (and actually very simple) approach for hyperparameter tuning that you've already learned in the lecture  is implementing a **Grid Search**.
#
#
#
# ## 3.1 Grid Search
# Grid search is a simple and naive, yet effective method to automate the hyperparameter tuning:
#
# * First, you define the set of parameters you want to tune, e.g. $\{learning\_rate, regularization\_strength\}$.
#
# * For each hyperparameter, you then define a set of possible values, e.g. $learning\_rate = \{0.0001, 0.001, 0.01, 0.1\}$.
#
# * Then, you train a model for every possible combination of these hyperparameter values and afterwards select the combination that works best (e.g. in terms of accuracy on your validation set).
#
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p>Check out our <code>grid_search</code> implementation in <code>../exercise_6/exercise_code/hyperparameter_tuning.py</code>. We show a simple for loop implementation and a more sophisticated one for multiple inputs. </p>
# </div>
#
#  <div class="alert alert-warning">
#     <h3>Note:</h3>
#     <p>To keep things simple for the beginning, it'll be enough to just focus on the hyperparameters <code>learning_rate</code> and <code>regularization_strength</code> here, as in the example above.</p>
# </div>

# %%
from exercise_code.networks import MyOwnNetwork

# Specify the used network
model_class = ClassificationNet

from exercise_code import hyperparameter_tuning
best_model, results = hyperparameter_tuning.grid_search(
    dataloaders['train_small'], dataloaders['val_500files'],
    grid_search_spaces = {
        "learning_rate": [1e-2, 1e-3, 1e-4], 
        "reg": [1e-4]
    },
    model_class=model_class,
    epochs=10, patience=5)
# Out:
# Evaluating Config #1 [of 3]:
#  {'learning_rate': 0.01, 'reg': 0.0001}
# (Epoch 1 / 10) train loss: 2.296809; val loss: 2.296817
# (Epoch 2 / 10) train loss: 0.102841; val loss: 0.012757
# (Epoch 3 / 10) train loss: 0.006404; val loss: 0.007319
# (Epoch 4 / 10) train loss: 0.002662; val loss: 0.001199
# (Epoch 5 / 10) train loss: 0.032909; val loss: 0.209594
# (Epoch 6 / 10) train loss: 0.061480; val loss: 0.008847
# (Epoch 7 / 10) train loss: 0.003452; val loss: 0.001213
# (Epoch 8 / 10) train loss: 0.000784; val loss: 0.000547
# (Epoch 9 / 10) train loss: 0.000468; val loss: 0.000417
# (Epoch 10 / 10) train loss: 0.000401; val loss: 0.000381
#
# Evaluating Config #2 [of 3]:
#  {'learning_rate': 0.001, 'reg': 0.0001}
# (Epoch 1 / 10) train loss: 2.302709; val loss: 2.302703
# (Epoch 2 / 10) train loss: 0.225514; val loss: 0.017299
# (Epoch 3 / 10) train loss: 0.009797; val loss: 0.007701
# (Epoch 4 / 10) train loss: 0.005589; val loss: 0.005375
# (Epoch 5 / 10) train loss: 0.004028; val loss: 0.003979
# (Epoch 6 / 10) train loss: 0.003119; val loss: 0.003088
# (Epoch 7 / 10) train loss: 0.002494; val loss: 0.002464
# (Epoch 8 / 10) train loss: 0.002045; val loss: 0.001994
# (Epoch 9 / 10) train loss: 0.001718; val loss: 0.001676
# (Epoch 10 / 10) train loss: 0.001481; val loss: 0.001424
#
# Evaluating Config #3 [of 3]:
#  {'learning_rate': 0.0001, 'reg': 0.0001}
# (Epoch 1 / 10) train loss: 2.297302; val loss: 2.297275
# (Epoch 2 / 10) train loss: 1.266080; val loss: 0.589452
# (Epoch 3 / 10) train loss: 0.343553; val loss: 0.219559
# (Epoch 4 / 10) train loss: 0.145014; val loss: 0.097316
# (Epoch 5 / 10) train loss: 0.076020; val loss: 0.058206
# (Epoch 6 / 10) train loss: 0.045831; val loss: 0.040603
# (Epoch 7 / 10) train loss: 0.031000; val loss: 0.034322
# (Epoch 8 / 10) train loss: 0.022128; val loss: 0.022279
# (Epoch 9 / 10) train loss: 0.016489; val loss: 0.017852
# (Epoch 10 / 10) train loss: 0.012924; val loss: 0.015144
#
# Search done. Best Val Loss = 0.00038052899468239666
# Best Config: {'learning_rate': 0.01, 'reg': 0.0001}

# %% [markdown]
# From the results of your grid search, you might already have found some hyperparameter combinations that work better than others. A common practice is to now repeat the grid search on a more narrow domain centered around the parameters that worked best.
#
# **Conclusion Grid Search**
#
# With grid search we now have automated the hyperparameter tuning to a certain degree. Another advantage is, that since the training of all models are independent of each other, you can parallelize the grid search, i.e.,  try out different hyperparameter configurations in parallel on different machines.
#
# However, as you have probably noticed, there is one big problem with this approach: the number of possible combinations to try out grows exponentially with the number of hyperparameters ("curse of dimensionality"). As we add more hyperparameters to the grid search, the search space will explode in time complexity, making this strategy unfeasible.

# %% [markdown]
# Especially when your search space contains more than 3 or 4 dimensions, it is often better to use another, similar hyperparameter tuning method that you've already learned about: random search.

# %% [markdown]
# ## 3.2 Random Search
# Random search is very similar to grid search, with the only difference, that instead of providing specific values for every hyperparameter, you only define a range for each hyperparameter - then, the values are sampled randomly from the provided ranges.
#
# ![alt text](https://i.stack.imgur.com/cIDuR.png "")
#
# The figure above illustrates the difference in the hyperparameter space exploration between grid search and random search: assume you have 2 hyperparameters with each 3 values. Running a grid search results in training $3^2=9$ different models - but in the end, you've just tired out 3 values for each parameter. For random search on the other hand, after training 9 models you'll have tried out 9 different values for each hyperparameter, which often leads much faster to good results.
#
# To get a deeper understanding of random search and why it is more efficient than grid search, you should definitely check out this paper: http://www.jmlr.org/papers/volume13/bergstra12a/bergstra12a.pdf
#
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p>Check out our <code>random_search</code> implementation in <code>../exercise_6/exercise_code/hyperparameter_tuning.py</code></p>
# </div>
#
#
# *Hint: regarding the sample space of each parameter, think about the scale for which it makes most sense to sample in. For example the learning rate is usually sampled on a logarithmic scale!*
#
# *For simplicity and speed, just use the `train_batches`-dataloader!*

# %%
from exercise_code.hyperparameter_tuning import random_search
from exercise_code.networks import MyOwnNetwork

# Specify the used network
model_class = ClassificationNet

best_model, results = random_search(
    dataloaders['train_small'], dataloaders['val_500files'],
    random_search_spaces = {
        "learning_rate": ([1e-2, 1e-6], 'log'),
        "reg": ([1e-3, 1e-7], "log"),
        "loss_func": ([CrossEntropyFromLogits()], "item")
    },
    model_class=model_class,
    num_search = 1, epochs=20, patience=5)
# Out:
# Evaluating Config #1 [of 1]:
#  {'learning_rate': 3.1282843422632147e-05, 'reg': 8.396334504872406e-05, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x7f77aa23b0d0>}
# (Epoch 1 / 20) train loss: 2.298652; val loss: 2.298656
# (Epoch 2 / 20) train loss: 1.915415; val loss: 1.514630
# (Epoch 3 / 20) train loss: 1.207688; val loss: 0.961066
# (Epoch 4 / 20) train loss: 0.758953; val loss: 0.610040
# (Epoch 5 / 20) train loss: 0.493728; val loss: 0.407901
# (Epoch 6 / 20) train loss: 0.340752; val loss: 0.287806
# (Epoch 7 / 20) train loss: 0.245527; val loss: 0.207916
# (Epoch 8 / 20) train loss: 0.184298; val loss: 0.156928
# (Epoch 9 / 20) train loss: 0.140891; val loss: 0.120670
# (Epoch 10 / 20) train loss: 0.110372; val loss: 0.094738
# (Epoch 11 / 20) train loss: 0.087121; val loss: 0.079953
# (Epoch 12 / 20) train loss: 0.070311; val loss: 0.063778
# (Epoch 13 / 20) train loss: 0.056572; val loss: 0.053163
# (Epoch 14 / 20) train loss: 0.046192; val loss: 0.043951
# (Epoch 15 / 20) train loss: 0.038265; val loss: 0.036918
# (Epoch 16 / 20) train loss: 0.031977; val loss: 0.031710
# (Epoch 17 / 20) train loss: 0.026700; val loss: 0.027100
# (Epoch 18 / 20) train loss: 0.022707; val loss: 0.023476
# (Epoch 19 / 20) train loss: 0.019372; val loss: 0.020326
# (Epoch 20 / 20) train loss: 0.016545; val loss: 0.018045
#
# Search done. Best Val Loss = 0.018044980140053256
# Best Config: {'learning_rate': 3.1282843422632147e-05, 'reg': 8.396334504872406e-05, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x7f77aa23b0d0>}

# %% [markdown]
# It's time to run it with the whole dataset, and let it search for a few hours for a nice configuration.
#
# However, to save some time, let's first implement an **early-stopping** mechanism, that you also already know from the lecture.

# %% [markdown]
# ## 3.3 Early Stopping

# %% [markdown]
# By now you've already seen a lot of training curves:
#
# <img src=http://fouryears.eu/wp-content/uploads/2017/12/early_stopping.png></img>
#
# Usually, at some point the validation loss goes up again, which is a sign that we're overfitting to our training data. Since it actually doesn't make any sense to train further at this point, it's common practice to apply "early stopping", i.e., cancel the training process when the validation loss doesn't improve anymore. The nice thing about this concept is, that not only it improves generalization through the prevention of overfitting, but also it saves us a lot of time - one of our most valuable resources in deep learning.
#
# Since there are natural fluctuations in the validation loss, you usually don't cancel the training process right at the first epoch when the validation-loss increases, but instead, you wait for some epochs (specified by the `patience`-parameter) and if the loss still doesn't improve, we stop.
#
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p>Please check the implementation of the early stopping mechanism in <code>../exercise_6/exercise_code/solver.py</code>.
#  </p>
# </div>

# %% [markdown]
# ## 3.4 Let's find the perfect model!

# %% [markdown]
# You've now set everything up to start training your model and
# finding a nice set of hyper parameters using a combination of grid or random search!
#
# Since we'll now be training with a much larger number of samples, you should be aware that this process will definitely take some time! So be prepared to let your machine run for a while.
#
# At the beginning, it's a good approach to first do a coarse random search across a wide range of values to find promising sub-ranges of your parameter space. Afterwards, you can zoom in to these ranges and do another random search (or grid search) to finetune the configuration.
#
# You don't have to use the whole dataset at the beginning, instead you can also use a medium large subset of the samples. Also, you don't need to train for a large number of epochs - as mentioned above: we first want to get an overview about our hyper parameters.
#
# <div class="alert alert-info">
#     <h3>Task: Hyperparameters Tunning & Model Training </h3>
#         <p> Now, it is your turn to do the hyperparamater tuning. In the cell below, you can use the <code>random_search</code> function to find a good choice of parameters. Put in some reasonable ranges for the hyperparameters and evaluate them.
#     <p> <b>Note:</b> At the beginning, it's a good approach to first do a coarse random search across a <b> wide range of values</b> to find promising sub-ranges of your parameter space and use <b> a medium large subset of the dataset </b>instead the whole as well. Afterwards, you can zoom in to these ranges and do another random search (or grid search) to finetune the configuration. Use the cell below to play around and find good hyperparameters for your model!</p>
#         <p> Finally, once you've found some promising hyperparameters (or narrowed them down to promising subranges), it's time to utilize these hyperparameters to train your network on the whole dataset for a large number of epochs so that your own model can reach an acceptable performance.
#         <p> <b>Hint:</b> You may use a <code>Solver</code> class we provided before or directly use the <code>random_search</code> function (as you can also monitor the loss here) for model training.
# </div>

# %%
from exercise_code.networks import MyOwnNetwork

best_model = ClassificationNet()
#best_model = MyOwnNetwork()

########################################################################
# TODO:                                                                #
# Implement your own neural network and find suitable hyperparameters  #
# Be sure to edit the MyOwnNetwork class in the following code snippet #
# to upload the correct model!                                         #
########################################################################

model_class = MyOwnNetwork

best_model, results = random_search(
    dataloaders['train_small'], dataloaders['val_500files'],
    random_search_spaces = {
        "learning_rate": ([1e-2, 1e-6], 'log'),
        "reg": ([1e-3, 1e-7], "log"),
        "loss_func": ([CrossEntropyFromLogits()], "item")
    },
    model_class=model_class,
    num_search = 1, epochs=5, patience=5)

model = MyOwnNetwork(num_layer=num_layer, reg=results[0][0]['reg'])
loss = CrossEntropyFromLogits()
solver = Solver(model, train_loader, dataloaders['val'], 
                learning_rate=results[0][0]['learning_rate'], loss_func=loss, optimizer=Adam)

solver.train(epochs=epochs)

########################################################################
#                           END OF YOUR CODE                           #
########################################################################
# Out:
# Evaluating Config #1 [of 1]:
#  {'learning_rate': 2.188855974073908e-06, 'reg': 0.0005370879676704681, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x7f779e432150>}
# (Epoch 1 / 5) train loss: 2.305668; val loss: 2.305666
# (Epoch 2 / 5) train loss: 2.280547; val loss: 2.255058
# (Epoch 3 / 5) train loss: 2.229656; val loss: 2.203363
# (Epoch 4 / 5) train loss: 2.177519; val loss: 2.150052
# (Epoch 5 / 5) train loss: 2.123818; val loss: 2.095085
#
# Search done. Best Val Loss = 2.0950849443403046
# Best Config: {'learning_rate': 2.188855974073908e-06, 'reg': 0.0005370879676704681, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x7f779e432150>}
# (Epoch 1 / 5) train loss: 2.302706; val loss: 2.302706
# (Epoch 2 / 5) train loss: 2.277575; val loss: 2.252224
# (Epoch 3 / 5) train loss: 2.226878; val loss: 2.201165
# (Epoch 4 / 5) train loss: 2.175248; val loss: 2.148889
# (Epoch 5 / 5) train loss: 2.122253; val loss: 2.095154

# %% [markdown]
# Now it's time to edit the ranges above and adjust them to explore regions that performed well!
#
# Also, feel free to experiment around! Also the network architecture, optimizer options and activations functions, etc. are hyperparameters that you can change!
#
# Try to get your accuracy as high as possible! That's all what counts for this submission!
#
# You'll pass if you reach at least **48%** accuracy on our test set - but there will also be a leaderboard of all students of this course. Will you make it to the top?

# %% [markdown]
# ## 3.5 Checking the validation accuracy

# %%
labels, pred, acc = best_model.get_dataset_prediction(dataloaders['train'])
print("Train Accuracy: {}%".format(acc*100))
labels, pred, acc = best_model.get_dataset_prediction(dataloaders['val'])
print("Validation Accuracy: {}%".format(acc*100))
# Out:
# Train Accuracy: 100.0%
# Validation Accuracy: 100.0%

# %% [markdown]
# # 4. Test your model
# When you have finished your hyperparameter tuning and are sure you have your final model that performs well on the validation set (**you should at least get 48% accuracy on the validation set!**), it's time to run your  model on the test set.
#
# <div class="alert alert-danger">
#     <h3>Important</h3>
#     <p>As you have learned in the lecture, you must only use the test set one single time! So only run the next cell if you are really sure your model works well enough and that you want to submit. Your test set is different from the test set on our server, so results may vary. Nevertheless, you will have a reasonable close approximation about your performance if you only do a final evaluation on the test set.</p>
#     <p>If you are an external student that can't use our submission webpage: this test performance is your final result and if you surpassed the threshold, you have completed this exercise :). Now, train again to aim for a better number!</p>
# </div>

# %%
# comment this part out to see your model's performance on the test set.
labels, pred, acc = best_model.get_dataset_prediction(dataloaders['test'])
print("Test Accuracy: {}%".format(acc*100))
# Out:
# Test Accuracy: 100.0%

# %% [markdown]
# <div class="alert alert-warning">
#     <h3>Note:</h3>
#     <p>The "real" test set is actually the dataset we're using for testing your model, which is <b>different</b> from the test-set you're using here.</p>
# </div>

# %% [markdown]
# # 5. Saving your Model

# %%
from exercise_code.tests import save_pickle
save_pickle({"cifar_fcn": best_model}, "cifar_fcn.p")

# %%
from exercise_code.submit import submit_exercise

submit_exercise('exercise06')
# Out:
# relevant folders: ['models']
# notebooks files: []
# Adding folder models
# Zipping successful! Zip is stored under: /content/exercise06.zip
