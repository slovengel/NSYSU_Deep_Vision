# %% [markdown]
# Final Project Demo
# ============

# %%
# !pip install pytorch-lightning
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 584 kB 5.2 MB/s
# ...
#      |████████████████████████████████| 596 kB 7.4 MB/s
# ...
#      |████████████████████████████████| 418 kB 36.9 MB/s
# ...
#      |████████████████████████████████| 140 kB 44.1 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 32.9 MB/s
# ...
#      |████████████████████████████████| 271 kB 53.3 MB/s
# ...
#      |████████████████████████████████| 94 kB 3.8 MB/s
# ...
#      |████████████████████████████████| 144 kB 55.9 MB/s
# ...
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
import os
print(os.getcwd())

from google.colab import drive
drive.mount('/content/drive')
# Out:
# /content
# Mounted at /content/drive

# %%
os.listdir()
GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = 'FinalProject/12/exercise_12'
GOOGLE_DRIVE_PATH = os.path.join('/content', 'drive', 'My Drive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
os.chdir(GOOGLE_DRIVE_PATH)
print(os.listdir(GOOGLE_DRIVE_PATH))
# Out:
# ['demo.ipynb', 'exercise_code', 'models', '.tmp', 'lightning_logs', 'images', 'weight3.pt', 'weight4.pt', 'weight5.pt', 'weight6.pt', 'weight7.pt', 'weight8.pt', 'weight9.pt', 'weight10.pt', 'weight11.pt', 'weight12.pt', 'weight13.pt', 'weight14.pt', 'weight15.pt', 'weight16.pt', 'weight17.pt', 'weight18.pt', 'weight19.pt', 'weight20.pt', 'prediction', 'weight21.pt', 'weight2.pt', 'training.ipynb']

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.autograd import Variable
import pytorch_lightning as pl

from exercise_code.data.segmentation_dataset import SegmentationData, label_img_to_rgb
from exercise_code.util import save_prediction
from exercise_code.util.Util import checkSize, checkParams
from exercise_code.networks.segmentation_nn import SegmentationNN

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0)
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = os.path.dirname(os.path.abspath(os.getcwd()))
data_root = os.path.join(path, 'datasets', 'segmentation')

demo_data = SegmentationData(image_paths_file=f'{data_root}/segmentation_data/demo.txt', folder='demo', val_type='.jpg')

# %%
hparams = {
    "height":240, "width":240, "loss":torch.nn.CrossEntropyLoss(ignore_index=0, reduction='mean'),
    "lr":1e-2, "train_dataset":demo_data, "batch_size":16
}

# %%
model = SegmentationNN(hparams=hparams)					
model.load_state_dict(torch.load('weight.pt'))
# Out:
# <All keys matched successfully>

# %%
print(len(demo_data))
# Out:
# 12

# %%
save_prediction(model, demo_data)
# Out:
# 1.png saved!
# 2.png saved!
# 3.png saved!
# 4.png saved!
# 5.png saved!
# 6.png saved!
# 7.png saved!
# 8.png saved!
# 9.png saved!
# 10.png saved!
# 11.png saved!
# 12.png saved!
